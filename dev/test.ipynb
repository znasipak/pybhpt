# %%
from pybhpt.geo import KerrGeodesic
from pybhpt.radial import RadialTeukolsky
from pybhpt.teuk import TeukolskyMode
from pybhpt.hertz import HertzMode
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Redshift Tests

# %%
from pybhpt.geo import kerrgeo_Vr
import numpy as np
def u2_ecc(geo):
    a = geo.blackholespin
    rp = geo.radialpoints
    En = geo.orbitalenergy
    Lz = geo.orbitalangularmomentum
    deltaUr = np.array([np.sqrt(kerrgeo_Vr(a, En, Lz, 0., r)) for r in rp])
    u2up = pow(rp*rp - 2.*rp + a*a, -1)*(En*(rp*rp + a*a) - a*Lz - deltaUr)
    u2down = pow(rp*rp - 2.*rp + a*a, -1)*(En*(rp*rp + a*a) - a*Lz + deltaUr)
    return np.concatenate((u2up, np.flip(u2down)[1:-1]))

def u3_ecc(geo):
    a = geo.blackholespin
    r = geo.radialpoints
    En = geo.orbitalenergy
    Lz = geo.orbitalangularmomentum
    z = 0.
    I = 1.j
    Uz = 0.
    u3up = (-I)*Uz*pow(I*r + a*z,-1)*pow(2. - 2.*pow(z,2),-0.5) + (Lz + a*En*(-1. + pow(z,2)))*pow(I*r + a*z,-1)*pow(2. - 2.*pow(z,2),-0.5)
    u3down = u3up
    return np.concatenate((u3up, np.flip(u3down)[1:-1]))

def u4_ecc(geo):
    return np.conj(u3_ecc(geo))

# %%
from pybhpt.geo import KerrGeodesic
from pybhpt.redshift import RedshiftCoefficients, SphericalHarmonicCoupling
geo = KerrGeodesic(0., 10., 0., 1.0, 2**6)
huucoeffIRG = RedshiftCoefficients("IRG", geo)
huucoeffORG = RedshiftCoefficients("ORG", geo)
huucoeffSAAB0 = RedshiftCoefficients("SAAB0", geo)
huucoeffSAAB4 = RedshiftCoefficients("SAAB4", geo)

# %%
from pybhpt.redshift import metric_coefficients_IRG
def huucoeff_ecc_check(a, b, c, d, geo):
    q = geo.blackholespin
    rhalf = geo.radialpoints
    rp = np.concatenate((rhalf, np.flip(rhalf)[1:-1]))
    z = 0.
    h22 = np.array([metric_coefficients_IRG(2, 2, a, b, c, d, q, r, z) for r in rp])
    h24 = np.array([metric_coefficients_IRG(2, 4, a, b, c, d, q, r, z) for r in rp])
    h44 = np.array([metric_coefficients_IRG(4, 4, a, b, c, d, q, r, z) for r in rp])
    u2 = u2_ecc(geo)
    u4 = u4_ecc(geo)
    return h22*u2*u2 + 2.*h24*u2*u4 + h44*u4*u4

# %%
# for a in range(3):
#     for b in range(3):
#         for c in range(3):
#             for d in range(3):
#                 if a + b + c + d <= 2:
#                     print(a, b, c, d)
#                     huuCheckFoo = [huucoeffIRG(0, a, b, c, d, i, 1) for i in range(2**6)]
#                     if np.abs(np.sum(huuCheckFoo)) > 0.:
#                         # foocheck = 1. - huuCheckFoo/huucoeff_ecc_check(a, b, c, d, geo)
#                         foocheck = huuCheckFoo - huucoeff_ecc_check(a, b, c, d, geo)
#                         print(np.max(np.abs(foocheck)))
#                         print(np.mean(huuCheckFoo))

# %%
from pybhpt.redshift import metric_coefficients_IRG
def u2_circ_norm(geo):
    Omega = geo.frequencies[-1]
    q = geo.blackholespin
    return (1. - q*Omega)

def u4_circ_norm(geo):
    Omega = geo.frequencies[-1]
    q = geo.blackholespin
    r0 = geo.semilatusrectum
    rhobar = -1./(r0 + 1j*q)
    return 1.j*rhobar*(q - (r0**2 + q**2)*Omega)/np.sqrt(2.)

def ut_circ(geo):
    v = 1./np.sqrt(geo.semilatusrectum)
    q = geo.blackholespin
    return (1. + q*v**3)/(np.sqrt(1 - 3*v**2 + 2.*q*v**3))

def u2_comp(geo):
    a = geo.blackholespin
    rp = geo.semilatusrectum
    En = geo.orbitalenergy
    Lz = geo.orbitalangularmomentum
    ut = ut_circ(geo)
    u2 = u2_circ_norm(geo)*ut
    u2_cpp = pow(rp*rp - 2.*rp + a*a, -1)*(En*(rp*rp + a*a) - a*Lz)
    return (1. - u2/u2_cpp)

def u4_comp(geo):
    a = geo.blackholespin
    r = geo.semilatusrectum
    En = geo.orbitalenergy
    Lz = geo.orbitalangularmomentum
    z = 0.
    I = 1.j
    ut = ut_circ(geo)
    u4 = u4_circ_norm(geo)*ut
    Uz = 0.
    u3_cpp = (-I)*Uz*pow(I*r + a*z,-1)*pow(2. - 2.*pow(z,2),-0.5) + (Lz + a*En*(-1. + pow(z,2)))*pow(I*r + a*z,-1)*pow(2. - 2.*pow(z,2),-0.5)
    return (1. - u4/np.conj(u3_cpp))

def huuIRGTest(geo, nt, nr, nc, np):
    r = geo.semilatusrectum
    z = 0.
    a = geo.blackholespin
    h22 = metric_coefficients_IRG(2, 2, nt, nr, nc, np, a, r, z)
    h24 = metric_coefficients_IRG(2, 4, nt, nr, nc, np, a, r, z)
    h44 = metric_coefficients_IRG(4, 4, nt, nr, nc, np, a, r, z)
    ut = ut_circ(geo)
    u2 = u2_circ_norm(geo)*ut
    u4 = u4_circ_norm(geo)*ut
    return 0.5*h22*u2*u2 + 2.*h24*u2*u4 + h44*u4*u4

# %%
# for a in range(3):
#     for b in range(3):
#         for c in range(3):
#             for d in range(3):
#                 if a + b + c + d <= 2:
#                     print(a, b, c, d)
#                     print(np.abs(huuIRGTest(geoCirc, a, b, c, d)-1.*huucoeffIRG(0, a, b, c, d)))

# %%
def h22_coeff_check(r):
    h22_schw_0020 = -1./(4.*r**2)
    h22_0020 = 0.5*metric_coefficients_IRG(2, 2, 0, 0, 2, 0, 0, r, 0)
    return 1. - h22_schw_0020/h22_0020

def h24_coeff_check(r):
    factor = -1/(2.*np.sqrt(2.)*r**2*(r - 2.))
    h24_schw_0010 = 2*(r-2)*factor
    h24_schw_1010 = -r**2*factor
    h24_schw_0110 = -r*(r-2)*factor
    h24_0010 = 0.5*metric_coefficients_IRG(2, 4, 0, 0, 1, 0, 0, r, 0)
    h24_1010 = 0.5*metric_coefficients_IRG(2, 4, 1, 0, 1, 0, 0, r, 0)
    h24_0110 = 0.5*metric_coefficients_IRG(2, 4, 0, 1, 1, 0, 0, r, 0)
    return 1. - h24_schw_0010/h24_0010, 1. - h24_schw_1010/h24_1010, 1. - h24_schw_0110/h24_0110

def h44_coeff_check(r):
    factor = 1./(2.*r*(r - 2)**2)
    h44_schw_1000 = (-2.*r + 2*r**2)*factor 
    h44_schw_2000 = (-r**3)*factor
    h44_schw_0100 = ((2 - r)*(4 - 2.*r))*factor
    h44_schw_1100 = ((2 - r)*(2*r**2))*factor
    h44_schw_0200 = (r*(r - 2)*(2 - r))*factor
    h44_1000 = 0.5*metric_coefficients_IRG(4, 4, 1, 0, 0, 0, 0, r, 0)
    h44_2000 = 0.5*metric_coefficients_IRG(4, 4, 2, 0, 0, 0, 0, r, 0)
    h44_0100 = 0.5*metric_coefficients_IRG(4, 4, 0, 1, 0, 0, 0, r, 0)
    h44_1100 = 0.5*metric_coefficients_IRG(4, 4, 1, 1, 0, 0, 0, r, 0)
    h44_0200 = 0.5*metric_coefficients_IRG(4, 4, 0, 2, 0, 0, 0, r, 0)
    return 1. - h44_schw_1000/h44_1000, 1. - h44_schw_2000/h44_2000, 1. - h44_schw_0100/h44_0100, 1. - h44_schw_1100/h44_1100, 1. - h44_schw_0200/h44_0200

# %%
def huu_coeff_check(geo, coeffs):
    r = geo.semilatusrectum
    Omega = geo.frequencies[-1]
    factor24 = -1/(2.*np.sqrt(2.)*r**2*(r - 2.))
    factor44 = 1./(2.*r*(r - 2)**2)

    h22_schw_0020 = -1./(4.*r**2)
    h24_schw_0010 = 2*(r-2)*factor24
    h24_schw_1010 = -r**2*factor24
    h24_schw_0110 = -r*(r-2)*factor24
    h44_schw_1000 = (-2.*r + 2*r**2)*factor44 
    h44_schw_2000 = (-r**3)*factor44
    h44_schw_0100 = ((2 - r)*(4 - 2.*r))*factor44
    h44_schw_1100 = ((2 - r)*(2*r**2))*factor44
    h44_schw_0200 = (r*(r - 2)*(2 - r))*factor44
    u2 = ut_circ(geo)
    u4 = 1.j/np.sqrt(2.)*r*ut_circ(geo)*Omega

    huu_0020 = h22_schw_0020*u2*u2
    huu_0010 = 2.*h24_schw_0010*u2*u4
    huu_1010 = 2.*h24_schw_1010*u2*u4
    huu_0110 = 2.*h24_schw_0110*u2*u4
    huu_1000 = h44_schw_1000*u4*u4
    huu_2000 = h44_schw_2000*u4*u4
    huu_0100 = h44_schw_0100*u4*u4
    huu_1100 = h44_schw_1100*u4*u4
    huu_0200 = h44_schw_0200*u4*u4

    test0 = [0.5*coeffs(0, 0, 0, 2, 0), huu_0020]
    test1 = [0.5*coeffs(0, 0, 0, 1, 0), huu_0010]
    test2 = [0.5*coeffs(0, 1, 0, 1, 0), huu_1010]
    test3 = [0.5*coeffs(0, 0, 1, 1, 0), huu_0110]
    test4 = [0.5*coeffs(0, 1, 0, 0, 0), huu_1000]
    test5 = [0.5*coeffs(0, 2, 0, 0, 0), huu_2000]
    test6 = [0.5*coeffs(0, 0, 1, 0, 0), huu_0100]
    test7 = [0.5*coeffs(0, 1, 1, 0, 0), huu_1100]
    test8 = [0.5*coeffs(0, 0, 2, 0, 0), huu_0200]

    tests = [test0, test1, test2, test3, test4, test5, test6, test7, test8]
    data_return = []
    for test in tests:
        data_return.append(1. - test[0]/test[1])

    return data_return

# huu_coeff_check(geoCirc, huucoeffIRG)

# %%
from scipy.special import factorial as fac
from pybhpt.redshift import w3j
import numpy as np

def muCoupling(s, l):
    """
    Eigenvalue for the spin-weighted spherical harmonic lowering operator
    Setting s -> -s gives the negative of the eigenvalue for the raising operator
    """
    if l + s < 0 or l - s + 1. < 0:
        return 0
    return np.sqrt((l - s + 1.)*(l + s))

def Asjlm(s, j, l, m):
    if s >= 0:
        return (-1.)**(m + s)*np.sqrt(4**s*fac(s)**2*(2*l + 1)*(2*j + 1)/fac(2*s))*w3j(s, l, j, 0, m, -m)*w3j(s, l, j, s, -s, 0)
    else:
        return (-1.)**(m)*np.sqrt(4**(-s)*fac(-s)**2*(2*l + 1)*(2*j + 1)/fac(-2*s))*w3j(-s, l, j, 0, m, -m)*w3j(-s, l, j, s, -s, 0)

def spin_operator_normalization(s, ns, l):
    s_sgn = np.sign(s)
    nmax1 = np.abs(s) + 1
    Jterm = 1.
    for ni in range(1, ns + 1):
        Jterm *= -s_sgn*muCoupling((nmax1-ni), l)
    return Jterm

# %%
# from pybhpt.redshift import Yslm
# from scipy.special import sph_harm
# def Yslm_check(s, l, m, th):
#     ths = np.ascontiguousarray(th)
#     ylm = np.zeros(ths.shape[0])
#     lmin = np.max([np.abs(m), l - np.abs(s)])
#     lmax = l + np.abs(s)
#     for j in range(lmin, lmax + 1):
#         ylm += Asjlm(s, j, l, m)*Yslm(0, j, m, ths)
#     return Yslm(s, l, m, ths), ylm/np.sin(ths)**np.abs(s)

# Yslm_check(1, 2, 2, 0.1)

# %%
from pybhpt.teuk import TeukolskyMode
from pybhpt.hertz import HertzMode
from pybhpt.redshift import Yslm
from scipy.special import sph_harm
import numpy as np

def full_libration(xp):
    return np.concatenate((xp, np.flip(xp[1:-1])))

def construct_hertz_radial_components(hertz, samples = 2**6):
    samples_half = int(samples/2 + 1)
    hertzR0In = np.array([hertz.radialsolution('In', i) for i in range(samples_half)])
    hertzR0Up = np.array([hertz.radialsolution('Up', i) for i in range(samples_half)])
    hertzR1In = np.array([hertz.radialderivative('In', i) for i in range(samples_half)])
    hertzR1Up = np.array([hertz.radialderivative('Up', i) for i in range(samples_half)])
    hertzR2In = np.array([hertz.radialderivative2('In', i) for i in range(samples_half)])
    hertzR2Up = np.array([hertz.radialderivative2('Up', i) for i in range(samples_half)])
    hertzR = np.array(
        [[np.concatenate((hertzR0In, np.flip(hertzR0In)[1:-1])), np.concatenate((hertzR0Up, np.flip(hertzR0Up)[1:-1]))], 
        [np.concatenate((hertzR1In, np.flip(hertzR1In)[1:-1])), np.concatenate((hertzR1Up, np.flip(hertzR1Up)[1:-1]))], 
        [np.concatenate((hertzR2In, np.flip(hertzR2In)[1:-1])), np.concatenate((hertzR2Up, np.flip(hertzR2Up)[1:-1]))]])
    return hertzR

def construct_hertz_radial_components_circ(hertz):
    i = 0
    hertzR0In = hertz.radialsolution('In', i)
    hertzR0Up = hertz.radialsolution('Up', i)
    hertzR1In = hertz.radialderivative('In', i)
    hertzR1Up = hertz.radialderivative('Up', i)
    hertzR2In = hertz.radialderivative2('In', i)
    hertzR2Up = hertz.radialderivative2('Up', i)
    hertzR = np.array(
        [[hertzR0In, hertzR0Up],
        [hertzR1In, hertzR1Up],
        [hertzR2In, hertzR2Up]]
    )
    return hertzR

def construct_hertz_polar_spin_weighting(hertz, samples = 2**6):
    samples_half = int(samples/2 + 1)
    th = np.array([hertz.polarpoint(i) for i in range(samples_half)])
    thp = full_libration(th)
    sth = np.sin(thp)
    spinWeightingPolar = np.array(
        [pow(sth, -2),
        pow(sth, -1),
        pow(sth, 0)]
    )
    return spinWeightingPolar

def redshift_mode_inc(coeffs, hertz, l, samples = 2**6):
    m = hertz.azimuthalmode
    omega = hertz.frequency
    s_sgn = np.sign(hertz.spinweight)
    huu = np.zeros((samples, 2), dtype=np.complex128)
    hertzR = construct_hertz_radial_components_circ(hertz)
    spinWeightingPolar = construct_hertz_polar_spin_weighting(hertz, samples=samples)
    for ns in range(0, 3):
        scalar_coupling = 0.
        llmin = np.max([np.abs(m), 2, l - 3 + ns])
        llmax = np.max([llmin, l + 3 - ns])
        for ll in range(llmin, llmax + 1):
            Jterm = spin_operator_normalization(s_sgn*2, ns, ll)
            scalar_coupling += Jterm*hertz.couplingcoefficient(ll)*Asjlm(s_sgn*(2-ns), l, ll, m)
        for nt in range(0, 3):
            for nph in range(0, 3):
                pref = (1.j*m)**nph*(-1.j*omega)**nt
                for nr in range(0, 3):
                    if nt + nr + ns + nph <= 2:
                        hNabcd0 = np.array([coeffs(0, nt, nr, ns, nph, 0, i) for i in range(samples)])
                        hNabcd0 *= spinWeightingPolar[ns]
                        hNabcd = np.array([hNabcd0, hNabcd0]).T
                        huuTerm = -pref*hNabcd*scalar_coupling*hertzR[nr]
                        # if np.sum(huuTerm) == 0 and np.sum(hNabcd0) != 0:
                        #     print(nt, nr, ns, nph)
                        #     print(pref, spinWeightingPolar[ns], scalar_coupling, hertzR[nr])
                        huu += huuTerm
    return huu

def redshift_mode_ecc(coeffs, hertz, l, samples = 2**6):
    m = hertz.azimuthalmode
    omega = hertz.frequency
    s_sgn = np.sign(hertz.spinweight)
    ylm = np.real(sph_harm(m, l, 0., 0.5*np.pi))
    huu = np.zeros((2, samples), dtype=np.complex128)
    if np.abs(ylm) == 0.:
        return huu
    hertzR = construct_hertz_radial_components(hertz, samples)
    for ns in range(0, 3):
        scalar_coupling = 0.
        llmin = np.max([np.abs(m), 2, l - 3 + ns])
        llmax = np.max([llmin, l + 3 - ns])
        for ll in range(llmin, llmax + 1):
            Jterm = spin_operator_normalization(s_sgn*2, ns, ll)
            scalar_coupling += Jterm*hertz.couplingcoefficient(ll)*Asjlm(s_sgn*(2-ns), l, ll, m)
        for nt in range(0, 3):
            for nph in range(0, 3):
                pref = (1.j*m)**nph*(-1.j*omega)**nt
                for nr in range(0, 3):
                    if nt + nr + ns + nph <= 2:
                        hNabcd0 = [coeffs(0, nt, nr, ns, nph, i, 0) for i in range(samples)]
                        hNabcd = np.array([hNabcd0, hNabcd0])
                        huuTerm = -pref*hNabcd*scalar_coupling*hertzR[nr]*ylm
                        huu += huuTerm
    return huu

def redshift_mode_calc(coeffs, hertz, l):
    m = hertz.azimuthalmode
    omega = hertz.frequency
    s_sgn = 1
    if np.sign(hertz.spinweight) < 0:
        s_sgn = -1
    ylm = np.real(sph_harm(m, l, 0., 0.5*np.pi))
    huu = np.array([0., 0.], dtype=np.complex128)
    if np.abs(ylm) == 0.:
        return huu
    hertzRIn = [hertz.radialsolution('In', 0), hertz.radialderivative('In', 0), hertz.radialderivative2('In', 0)]
    hertzRUp = [hertz.radialsolution('Up', 0), hertz.radialderivative('Up', 0), hertz.radialderivative2('Up', 0)]
    for ns in range(0, 3):
        scalar_coupling = 0.
        llmin = np.max([np.abs(m), 2, l - 3 + ns])
        llmax = l + 3 - ns
        for ll in range(llmin, llmax + 1):
            Jterm = spin_operator_normalization(s_sgn*2, ns, ll)
            scalar_coupling += Jterm*hertz.couplingcoefficient(ll)*Asjlm(s_sgn*(2-ns), l, ll, m)
        # print(scalar_coupling, ns, l, hertz.spheroidalmode)
        for nt in range(0, 3):
            for nph in range(0, 3):
                pref = (1.j*m)**nph*(-1.j*omega)**nt
                for nr in range(0, 3):
                    if nt + nr + ns + nph <= 2:
                        hNabcd = coeffs(0, nt, nr, ns, nph)
                        if(abs(hNabcd) > 0.):
                            huuTerm = -pref*hNabcd*scalar_coupling*np.array([hertzRIn[nr], hertzRUp[nr]])*ylm
                            # if np.abs(huuTerm[0]) + np.abs(huuTerm[1]) > 0:
                            #     print(nt, nr, ns, nph, huuTerm)
                            huu += huuTerm
    return huu

from tqdm import tqdm

def redshift_calc(gauge, lmax, geo):
    if isinstance(gauge, str):
        if gauge == "SAAB":
            return redshift_calc(["SAAB0", "SAAB4"], lmax, geo)
        elif gauge == "ASAAB":
            return redshift_calc(["ASAAB0", "ASAAB4"], lmax, geo)
        gauges = [gauge]
    else:
        gauges = gauge
    coeffs = []
    for gauge in gauges:
        coeffs.append(RedshiftCoefficients(gauge, geo))
    huuYlm = np.zeros((lmax + 1, lmax + 1, 2), dtype=np.complex128)
    s = choose_spin_from_gauge(gauges[0])
    for m in tqdm(range(0, lmax + 1)):
        jmin = np.max([2, abs(m)])
        jmax = lmax + 4 + int(20*geo.blackholespin)
        for j in range(jmin, jmax + 1):
            teuk = TeukolskyMode(s, j, m, 0, 0, geo)
            teuk.solve(geo)
            psis = []
            for i, gauge in enumerate(gauges):
                psis.append(HertzMode(teuk, gauge))
                psis[i].solve()

            for l in range(abs(m), lmax + 1):
                # huuMode = redshift_mode_calc(coeffs, hertz, l)
                # huuYlm[l, m] += huuMode
                for coeff, psi in zip(coeffs, psis):
                        huuMode = redshift_mode_calc(coeff, psi, l)
                        if np.isnan(np.sum(huuMode)):
                            print("Error ", j, l, m)
                        else:
                            huuTemp = huuMode
                            # if l == j:
                            #     print(l, m, k)
                            #     print(orbit_average_polar(huuTemp, geo, axis = 0))
                            huuYlm[l, m] += huuTemp
    
    huuYl = np.zeros((lmax + 1, 2))
    for l in range(0, lmax + 1):
        huuYl[l] += 2.*np.real(huuYlm[l, 0])
        for m in range(1, l + 1):
            huuYl[l] +=  4.*np.real(huuYlm[l, m])

    return huuYl, huuYlm

def redshift_calc_ecc(gauge, lmax, geo, nrange = [-10, 10]):
    if isinstance(gauge, str):
        if gauge == "SAAB":
            return redshift_calc_ecc(["SAAB0", "SAAB4"], lmax, geo, nrange=nrange)
        elif gauge == "ASAAB":
            return redshift_calc_ecc(["ASAAB0", "ASAAB4"], lmax, geo, nrange=nrange)
        gauges = [gauge]
    else:
        gauges = gauge
    coeffs = []
    for gauge in gauges:
        coeffs.append(RedshiftCoefficients(gauge, geo))
    samples = 2*(geo.radialpoints.shape[0] - 1)
    huuYlm = np.zeros((lmax + 1, lmax + 1, 2, samples), dtype=np.complex128)
    s = choose_spin_from_gauge(gauges[0])
    for m in tqdm(range(0, lmax + 1)):
        jmin = np.max([abs(s), abs(m)])
        jmax = lmax + 4 + int(20)
        for j in range(jmin, jmax + 1):
            nmin = nrange[0]
            nmax = nrange[1]
            for n in range(nmin, nmax + 1):
                teuk = TeukolskyMode(s, j, m, 0, n, geo)
                teuk.solve(geo)
                psis = []
                for i, gauge in enumerate(gauges):
                    psis.append(HertzMode(teuk, gauge))
                    psis[i].solve()
                phaseUp = m*geo.azimuthalradial - teuk.frequency*geo.timeradial
                phaseDown = np.flip(-phaseUp)[1:-1]
                phase = np.concatenate((phaseUp, phaseDown)) - 2.*np.pi*n*np.arange(samples)/samples
                for l in range(abs(m), lmax + 1):
                    # huuMode = redshift_mode_ecc(coeffs, hertz, l, samples=samples)
                    # # if l == j and l < 5:
                    # #     print(l, m, n, np.mean(huuMode, axis = 1))
                    # if np.isnan(np.sum(huuMode)):
                    #     print(j, l, m, n)
                    # else:
                    #     huuYlm[l, m] += huuMode*np.exp(1.j*np.array([phase, phase]))
                    for coeff, psi in zip(coeffs, psis):
                        huuMode = redshift_mode_ecc(coeff, psi, l, samples=samples)
                        if np.isnan(np.sum(huuMode)):
                            print("Error ", j, l, m, n)
                        else:
                            huuTemp = huuMode*np.exp(1.j*np.array([phase, phase]))
                            # if l == j:
                            #     print(l, m, k)
                            #     print(orbit_average_polar(huuTemp, geo, axis = 0))
                            huuYlm[l, m] += huuTemp
    
    huuYl = np.zeros((lmax + 1, 2, samples))
    for l in range(0, lmax + 1):
        huuYl[l] += 2.*np.real(huuYlm[l, 0])
        for m in range(1, l + 1):
            huuYl[l] += 4.*np.real(huuYlm[l, m])

    return huuYl, huuYlm

def choose_spin_from_gauge(gauge):
    if gauge == "ORG" or gauge == "SAAB4" or gauge == "ASAAB4":
        s = 2
    else:
        s = -2
    return s

def redshift_calc_inc(gauge, lmax, geo, krange = [-10, 10]):
    if isinstance(gauge, str):
        if gauge == "SAAB":
            return redshift_calc_inc(["SAAB0", "SAAB4"], lmax, geo, krange=krange)
        elif gauge == "ASAAB":
            return redshift_calc_inc(["ASAAB0", "ASAAB4"], lmax, geo, krange=krange)
        gauges = [gauge]
    else:
        gauges = gauge
    coeffs = []
    for gauge in gauges:
        coeffs.append(RedshiftCoefficients(gauge, geo))
    samples = 2*(geo.polarpoints.shape[0] - 1)
    huuYlm = np.zeros((lmax + 1, lmax + 1, samples, 2), dtype=np.complex128)
    Ylms = np.zeros((lmax + 1, lmax + 1, samples, 2))
    th = geo.polarpoints
    thp = full_libration(th)
    for m in range(-lmax, lmax + 1):
        for l in range(m, lmax + 1):
            ylm0 = np.array([np.real(sph_harm(m, l, 0., th)) for th in thp])
            ylm = np.array([ylm0, ylm0]).T
            Ylms[l, m] = ylm
    s = choose_spin_from_gauge(gauges[0])
    for m in tqdm(range(0, lmax + 1)):
        jmin = np.max([abs(s), abs(m)])
        jmax = lmax + 4 + int(20*geo.blackholespin)
        for j in range(jmin, jmax + 1):
            kmin = krange[0]
            kmax = krange[1]
            for k in range(kmin, kmax + 1):
                teuk = TeukolskyMode(s, j, m, k, 0, geo)
                teuk.solve(geo)
                psis = []
                for i, gauge in enumerate(gauges):
                    psis.append(HertzMode(teuk, gauge))
                    psis[i].solve()
                phaseUp = m*geo.azimuthalpolar - teuk.frequency*geo.timepolar
                phaseDown = np.flip(-phaseUp)[1:-1]
                phase = np.concatenate((phaseUp, phaseDown)) - 2.*np.pi*k*np.arange(samples)/samples
                phaseArray = np.array([phase, phase]).T
                for l in range(abs(m), lmax + 1):
                    for coeff, psi in zip(coeffs, psis):
                        huuMode = redshift_mode_inc(coeff, psi, l, samples=samples)
                        if np.isnan(np.sum(huuMode)):
                            print("Error ", j, l, m, k)
                        else:
                            huuTemp = huuMode*np.exp(1.j*phaseArray)*Ylms[l, m]
                            # if l == j:
                            #     print(l, m, k)
                            #     print(orbit_average_polar(huuTemp, geo, axis = 0))
                            if gauge == "SAAB0" or gauge == "SAAB4":
                                huuYlm[l, m] += (-1)**k*huuTemp
                            else:
                                huuYlm[l, m] += huuTemp
    
    huuYl = np.zeros((lmax + 1, samples, 2))
    for l in range(0, lmax + 1):
        huuYl[l] += 2.*np.real(huuYlm[l, 0])
        for m in range(1, l + 1):
            huuYl[l] += 2.*np.real(huuYlm[l, m])
            huuYl[l] += 2.*np.real(np.roll(huuYlm[l, m], int(samples/2)))

    return huuYl, huuYlm

# %%
def huu_mode_check(gauge, j, m, k, n, geo):
    coeffs = RedshiftCoefficients(gauge, geo)
    samples = 2*(geo.polarpoints.shape[0] - 1)
    lmax = j + 10
    huuYlm = np.zeros((lmax + 1, 2*lmax + 1, samples, 2), dtype=np.complex128)
    Ylms = np.zeros((lmax + 1, 2*lmax + 1, samples, 2))
    th = geo.polarpoints
    thp = full_libration(th)
    for emmm in range(-lmax, lmax + 1):
        for l in range(m, lmax + 1):
            ylm0 = np.array([np.real(sph_harm(emmm, l, 0., th)) for th in thp])
            ylm = np.array([ylm0, ylm0]).T
            Ylms[l, emmm] = ylm
    s = -2
    if gauge == "ORG":
        s = 2
    teuk = TeukolskyMode(s, j, m, k, 0, geo)
    teuk.solve(geo)
    hertz = HertzMode(teuk, gauge)
    hertz.solve()
    phaseUp = m*geo.azimuthalpolar - teuk.frequency*geo.timepolar
    phaseDown = np.flip(-phaseUp)[1:-1]
    phase = np.concatenate((phaseUp, phaseDown)) - 2.*np.pi*k*np.arange(samples)/samples
    phaseArray = np.array([phase, phase]).T
    huuTemp = []
    for l in range(abs(m), lmax + 1):
        huuMode = redshift_mode_inc(coeffs, hertz, l, samples=samples)
        if np.isnan(np.sum(huuMode)):
            print(j,l,m,k)
        else:
            huuTemp.append(huuMode*np.exp(1.j*phaseArray)*Ylms[l, m])
    return huuTemp

# %%
# geoTest = KerrGeodesic(0.5, 10., 0., 0.9, 2**6)
# huuP=huu_mode_check("IRG", 4, 1, 0, 0, geoTest)
# huuM=huu_mode_check("IRG", 4, -1, 0, 0, geoTest)

# %%
from scipy.special import ellipk
from pybhpt.geo import kerrgeo_Vt_radial, kerrgeo_Vt_polar, kerrgeo_Vr, kerrgeo_Vtheta, kerrgeo_Vphi_radial, kerrgeo_Vphi_polar

def huu_reg_ecc(geo):
    L = geo.orbitalangularmomentum
    r0 = np.concatenate((geo.radialpoints, np.flip(geo.radialpoints)[1:-1]))
    q = geo.blackholespin
    kappa = L**2 + q**2 + 2*q**2/r0
    k = kappa/(r0**2 + kappa)
    K = ellipk(k)
    return 4.*K/(np.pi*np.sqrt(kappa + r0**2))

def huu_reg_inc(geo):
    En = geo.orbitalenergy
    Lz = geo.orbitalangularmomentum
    Qc = geo.carterconstant
    r = geo.radialpoints[0]
    th0 = np.concatenate((geo.polarpoints, np.flip(geo.polarpoints)[1:-1]))
    q = geo.blackholespin
    return huu_reg_gen(q, En, Lz, Qc, r, th0)

def huu_reg_gen(q, En, Lz, Qc, r, th):
    sig = r**2 + q**2*np.cos(th)**2
    eta = pow(sig,-1)*pow(2.*(2.*r + sig)*pow(q,2)*(sig*(-1.*Qc + pow(Lz,2)) + (2.*r + sig*pow(En,2))*(-1.*sig + pow(r,2))) + pow(q,4)*pow(2.*r + sig,2) + pow(sig*(Qc + pow(Lz,2)) - (2.*r + sig*pow(En,2))*(-1.*sig + pow(r,2)),2),0.5)
    zeta = Qc - 1.*r*(2. + r*(-2. + pow(En,2))) + sig*pow(En,2) + pow(Lz,2) + pow(q,2) + 2.*r*(pow(q,2) + pow(r,2))*pow(sig,-1)
    k = 2*eta/(eta + zeta)
    K = ellipk(k)
    return 4.*K/(np.pi*np.sqrt(eta/k))

def completion(geo):
    dM = geo.orbitalenergy
    dJ = geo.orbitalangularmomentum
    r = geo.radialpoints[0]
    q = geo.blackholespin
    htt = 2*dM/r
    htphi = -2*dJ/r
    hphiphi = 2.*q*((r + 2.)*dJ - (r + 1)*q*dM)/r
    Omega = geo.frequencies[-1]
    ut = ut_circ(geo)
    return ut**2*(htt + 2.*Omega*htphi + Omega**2*hphiphi)

def ut_ecc(q, En, Lz, r):
    Sigma = r**2
    theta = 0.5*np.pi
    Qc = 0.
    return (np.array([kerrgeo_Vt_radial(q, En, Lz, Qc, ri) for ri in r]) + kerrgeo_Vt_polar(q, En, Lz, Qc, theta))/Sigma

def uphi_ecc(q, En, Lz, r):
    Sigma = r**2
    theta = 0.5*np.pi
    Qc = 0.
    return (np.array([kerrgeo_Vphi_radial(q, En, Lz, Qc, ri) for ri in r]) + kerrgeo_Vphi_polar(q, En, Lz, Qc, theta))/Sigma

def ur_ecc(q, En, Lz, r):
    r0 = np.unique(r)
    Sigma = r**2
    Qc = 0.
    urUp = np.sqrt(np.abs(np.array([kerrgeo_Vr(q, En, Lz, Qc, ri) for ri in r0])))
    urUp[0] = 0.
    urUp[-1] = 0.
    urDown = -np.flip(urUp)[1:-1]
    ur = np.concatenate((urUp, urDown))/Sigma
    return ur

def ut_ecc_geo(geo):
    dM = geo.orbitalenergy
    dJ = geo.orbitalangularmomentum
    r = np.concatenate((geo.radialpoints, np.flip(geo.radialpoints)[1:-1]))
    q = geo.blackholespin
    return ut_ecc(q, dM, dJ, r)

def ur_ecc_geo(geo):
    dM = geo.orbitalenergy
    dJ = geo.orbitalangularmomentum
    r = np.concatenate((geo.radialpoints, np.flip(geo.radialpoints)[1:-1]))
    q = geo.blackholespin
    return ur_ecc(q, dM, dJ, r)

def uphi_ecc_geo(geo):
    dM = geo.orbitalenergy
    dJ = geo.orbitalangularmomentum
    r = np.concatenate((geo.radialpoints, np.flip(geo.radialpoints)[1:-1]))
    q = geo.blackholespin
    return uphi_ecc(q, dM, dJ, r)

def completion_ecc(geo):
    dM = geo.orbitalenergy
    dJ = geo.orbitalangularmomentum
    r = np.concatenate((geo.radialpoints, np.flip(geo.radialpoints)[1:-1]))
    q = geo.blackholespin
    htt = 2*dM/r
    hrr = 2.*r**2*((r + q**2)*dM - q*dJ)/(r**2 - 2.*r + q**2)**2
    htphi = -2*dJ/r
    hphiphi = 2.*q*((r + 2.)*dJ - (r + 1)*q*dM)/r
    ut = ut_ecc(q, dM, dJ, r)
    uphi = uphi_ecc(q, dM, dJ, r)
    ur = ur_ecc(q, dM, dJ, r)
    # return np.mean(r**2*(htt*ut*ut + 2*htphi*ut*uphi + hrr*ur*ur + hphiphi*uphi*uphi))/np.mean(r**2)
    return (htt*ut*ut + 2*htphi*ut*uphi + hrr*ur*ur + hphiphi*uphi*uphi)

def ut_inc(q, En, Lz, Qc, r, th):
    Sigma = r**2 + q**2*np.cos(th)**2
    return (np.array([kerrgeo_Vt_polar(q, En, Lz, Qc, thi) for thi in th]) + kerrgeo_Vt_radial(q, En, Lz, Qc, r))/Sigma

def uphi_inc(q, En, Lz, Qc, r, th):
    Sigma = r**2 + q**2*np.cos(th)**2
    return (np.array([kerrgeo_Vphi_polar(q, En, Lz, Qc, thi) for thi in th]) + kerrgeo_Vphi_radial(q, En, Lz, Qc, r))/Sigma

def uth_inc(q, En, Lz, Qc, r, th):
    th0 = np.unique(th)
    Sigma = r**2 + q**2*np.cos(th)**2
    uthUp = np.sqrt(np.abs(np.array([kerrgeo_Vtheta(q, En, Lz, Qc, thi) for thi in th0])))
    uthUp[0] = 0.
    uthUp[-1] = 0.
    uthDown = -np.flip(uthUp)[1:-1]
    uth = np.concatenate((uthUp, uthDown))/Sigma
    return uth

def completion_inc(geo):
    dM = geo.orbitalenergy
    dJ = geo.orbitalangularmomentum
    Qc = geo.carterconstant
    th = np.concatenate((geo.polarpoints, np.flip(geo.polarpoints)[1:-1]))
    z = np.cos(th)
    r = geo.radialpoints[0]
    q = geo.blackholespin
    sigma = r**2 + q**2*z**2
    httM = 2*(sigma + 2*q**2*z**2)
    httJ = -4*q*r*z**2
    hththM = -2*q**2*z**2*sigma**2
    hththJ = 2*q*z**2*sigma**2
    htphiM = -4*q**3*z**2*(1. - z**2)
    htphiJ = -2*(1 - z**2)*(sigma - 2*q**2*z**2)
    hphiphiM = -2*q**2*(1. - z**2)*(r**4 + 2*q**2*r**2*z**2 + q**4*z**4 + r**3*(1. - z**2) - q**2*r*z**2*(1. - z**2))
    hphiphiJ = 2*q*(1. - z**2)*(r**4 + 2*q**2*r**2*z**2 + q**4*z**4 + 2*r**3*(1. - z**2))
    ut = ut_inc(q, dM, dJ, Qc, r, th)
    uphi = uphi_inc(q, dM, dJ, Qc, r, th)
    uth = uth_inc(q, dM, dJ, Qc, r, th)
    htt = httM*dM + httJ*dJ
    htphi = htphiM*dM + htphiJ*dJ
    hphiphi = hphiphiM*dM + hphiphiJ*dJ
    hthth = hththM*dM + hththJ*dJ
    return (htt*ut*ut + 2*htphi*ut*uphi + hphiphi*uphi*uphi + hthth*uth*uth)/sigma**2

def orbit_average_ecc(func, geo, axis = 0):
    r = np.concatenate((geo.radialpoints, np.flip(geo.radialpoints)[1:-1]))
    return np.mean(func*r**2, axis = axis)/np.mean(r**2)

def orbit_average_inc(func, geo, axis = 0):
    th = np.concatenate((geo.polarpoints, np.flip(geo.polarpoints)[1:-1])).T
    r = geo.radialpoints[0]
    q = geo.blackholespin
    sig = r**2 + q**2*np.cos(th)**2
    if len(func.shape) <= 1:
        sigA = np.array(sig)
    else:
        sigA = np.array([sig, sig]).T
    return np.mean(func*sigA, axis = axis)/np.mean(sig)

# %%
# def Tr_ecc_geo(geo):
#     dM = geo.orbitalenergy
#     dJ = geo.orbitalangularmomentum
#     r = np.concatenate((geo.radialpoints, np.flip(geo.radialpoints)[1:-1]))
#     q = geo.blackholespin
#     return 2.*np.pi/geoEcc.minofrequencies[1]*np.mean(ut_ecc(q, dM, dJ, r)*r**2)
    
# def TTr_ecc_geo(geo):
#     dM = geo.orbitalenergy
#     dJ = geo.orbitalangularmomentum
#     r = np.concatenate((geo.radialpoints, np.flip(geo.radialpoints)[1:-1]))
#     q = geo.blackholespin
#     return 2.*np.pi/geoEcc.minofrequencies[1]*np.mean(r**2)

def Tr_ecc_geo_ratio(geo):
    dM = geo.orbitalenergy
    dJ = geo.orbitalangularmomentum
    r = np.concatenate((geo.radialpoints, np.flip(geo.radialpoints)[1:-1]))
    q = geo.blackholespin
    return np.mean(ut_ecc(q, dM, dJ, r)*r**2)/np.mean(r**2)

def Tth_inc_geo_ratio(geo):
    dM = geo.orbitalenergy
    dJ = geo.orbitalangularmomentum
    Qc = geo.carterconstant
    th = np.concatenate((geo.polarpoints, np.flip(geo.polarpoints)[1:-1]))
    r = geo.radialpoints[0]
    q = geo.blackholespin
    Sigma = r**2 + q**2*np.cos(th)**2
    return np.mean(ut_inc(q, dM, dJ, Qc, r, th)*Sigma)/np.mean(Sigma)

# %% [markdown]
# ## Circ Test

# %%
geoCirc = KerrGeodesic(0.9, 4., 0., 1.0, 2**2)
lmax = 30
huuCircIRG = redshift_calc('IRG', lmax, geoCirc)
huuCircORG = redshift_calc('ORG', lmax, geoCirc)
huuCircSAAB = redshift_calc('SAAB', lmax, geoCirc)
# Out:
# 100%|██████████| 31/31 [01:04<00:00,  2.07s/it]
# 100%|██████████| 31/31 [01:15<00:00,  2.42s/it]
# 100%|██████████| 31/31 [02:11<00:00,  4.23s/it]

# %%
# plt.plot(np.abs(np.mean(huuData[0][1:], axis=2)))
lmaxTemp = huuCircIRG[0].shape[0] - 1
# lmaxTemp = lmax
lmodes = np.arange(1., lmaxTemp+1)
huuregB = orbit_average_ecc(huu_reg_ecc(geoCirc), geoCirc)
huul = huuCircORG[0][:lmaxTemp+1]
huul2 = huuCircIRG[0][:lmaxTemp+1]
huul3 = 4.*huuCircSAAB[0][:lmaxTemp+1]
data = huul
datareg1 = huul - huuregB
datareg2 = huul2 - huuregB
datareg3 = huul3 - huuregB
ymin = np.min(np.abs(datareg[1:]))/5
ymax = 5*np.max(np.abs(datareg[1:]))
plt.figure(figsize=(10,10))
plt.loglog(lmodes, np.abs(data[1:, 1]), 'o', label = '$h_{uu}^{l,\mathrm{ORG}}$', mfc='none', ms=10)
plt.loglog(lmodes, np.abs(datareg1[1:, 1]), 'v', label = '$h_{uu}^{l,\mathrm{ORG}} - \Phi^S_{[0]}$', mfc='none', ms=10)
plt.loglog(lmodes, np.abs(datareg2[1:, 1]), 's', label = '$h_{uu}^{l,\mathrm{IRG}} - \Phi^S_{[0]}$', mfc='none', ms=10)
plt.loglog(lmodes, np.abs(datareg3[1:, 1]), 'D', label = '$h_{uu}^{l,\mathrm{sAAB}} - \Phi^S_{[0]}$', mfc='none', ms=10)
# plt.loglog(lmodes, np.abs(datareg[1:, 1]), '.')
for i in range(20):
    plt.loglog(lmodes, ymax*10.**(2-0.5*i)*lmodes**(-2), '--', color='gray')
plt.ylim(ymin, ymax)
plt.xlim(1, lmaxTemp)
plt.xlabel("$l$")
plt.ylabel("$|h_{uu}^{R,l}|$")
plt.gca().set_xticks([1, 2, 5, 10, 20])
plt.gca().get_xaxis().set_major_formatter(mpl.ticker.ScalarFormatter())
plt.legend()
plt.show()

# %%
from scipy.optimize import lsq_linear
def lbasis(lmax):
    return [1., ((lmax + 1)), ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3)), ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3)/(2*lmax - 1)/(2*lmax + 5))]

lminTest = 22
lmaxTest = lmax
ysum = np.array([np.sum(huul[:lmax + 1, 1]) for lmax in range(lminTest, lmaxTest + 1)])
xsum = np.array([lbasis(lmax) for lmax in range(lminTest, lmaxTest + 1)])

b = lsq_linear(xsum, ysum)
print(b.x[1] - huuregB)
hcomp = completion(geoCirc)
zval = 0.5*(b.x[0] + hcomp)*Tr_ecc_geo_ratio(geoCirc)
print(zval)
# Out:
# 5.43198486191443e-10
# -0.32570447719335033

# %%
from scipy.optimize import lsq_linear
def lbasis(lmax):
    return [1., ((lmax + 1)), ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3)), ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3)/(2*lmax - 1)/(2*lmax + 5))]

def lfit(huul, lminTest, lmaxTest):
    ysum = np.array([np.sum(huul[:lmax + 1, 1]) for lmax in range(lminTest, lmaxTest + 1)])
    xsum = np.array([lbasis(lmax) for lmax in range(lminTest, lmaxTest + 1)])
    b = lsq_linear(xsum, ysum)
    return b.x[0], b.x[1]

def redshift_fit_recon(huul, geo, lmins = [10, 15], lmaxs = [25, 30]):
    huuregB = orbit_average_ecc(huu_reg_ecc(geo), geo)
    huuTest = []
    huuRegTest = []
    for lmin in range(lmins[0], lmins[1]):
        for lmax in range(lmaxs[0], lmaxs[1]):
            b = lfit(huul, lmin, lmax)
            huuTest.append(b[0])
            huuRegTest.append(b[1])

    huus = np.sort(np.array(huuTest))
    return np.mean(huus), np.sqrt(np.cov(huus)), np.mean(huuRegTest) - huuregB

def redshift_fit(huul, geo, lmins = [10, 15], lmaxs = [25, 30]):
    huuData = redshift_fit_recon(huul, geo, lmins = lmins, lmaxs = lmaxs)
    hcomp =  orbit_average_ecc(completion_ecc(geo), geo)
    zval = 0.5*(huuData[0] + hcomp)*Tr_ecc_geo_ratio(geo)
    zerr = 0.5*(huuData[1])*Tr_ecc_geo_ratio(geo)
    return zval, 3.*zerr, huuData[2]

# %%
huul = 4.*huuCircSAAB[0][:lmaxTemp+1]
redshift_fit(huul, geoCirc, lmins=[15,20], lmaxs=[27,30])
# Out:
# (-0.3257075981798068, 2.561729500584125e-06, 5.3265249433387396e-08)

# %%
geoCirc = KerrGeodesic(0., 10., 0., 1.0, 2**2)
lmax = 30
huuCirc = redshift_calc('SAAB', lmax, geoCirc)
# Out:
# 100%|██████████| 31/31 [00:40<00:00,  1.30s/it]

# %%
huuDeltaRG = redshift_calc('IRG', lmax, geoCirc)[1] + redshift_calc('ORG', lmax, geoCirc)[1]
# Out:
# 100%|██████████| 31/31 [00:20<00:00,  1.50it/s]
# 100%|██████████| 31/31 [00:19<00:00,  1.57it/s]

# %%
huuCircASAAB0 = redshift_calc('ASAAB0', lmax, geoCirc)
huuCircASAAB4 = redshift_calc('ASAAB4', lmax, geoCirc)
# Out:
#   0%|          | 0/31 [00:00<?, ?it/s]/Users/znasipak/opt/anaconda3/envs/pybhpt-env/lib/python3.7/site-packages/ipykernel_launcher.py:134: RuntimeWarning: invalid value encountered in multiply
# Error  2 0 0
# Error  2 2 0
# Error  2 3 0
# Error  2 4 0
# Error  2 5 0
# Error  2 6 0
# Error  2 7 0
# Error  2 8 0
# Error  2 9 0
# Error  2 10 0
# Error  2 11 0
# Error  2 12 0
# Error  2 13 0
# Error  2 14 0
# Error  2 15 0
# Error  2 16 0
# Error  2 17 0
# Error  2 18 0
# Error  2 19 0
# Error  2 20 0
# Error  2 21 0
# Error  2 22 0
# Error  2 23 0
# Error  2 24 0
# Error  2 25 0
# Error  2 26 0
# Error  2 27 0
# Error  2 28 0
# Error  2 29 0
# Error  2 30 0
# Error  3 0 0
# Error  3 2 0
# Error  3 3 0
# Error  3 4 0
# Error  3 5 0
# Error  3 6 0
# Error  3 7 0
# Error  3 8 0
# Error  3 9 0
# Error  3 10 0
# Error  3 11 0
# Error  3 12 0
# Error  3 13 0
# Error  3 14 0
# Error  3 15 0
# Error  3 16 0
# Error  3 17 0
# Error  3 18 0
# Error  3 19 0
# Error  3 20 0
# Error  3 21 0
# Error  3 22 0
# Error  3 23 0
# Error  3 24 0
# Error  3 25 0
# Error  3 26 0
# Error  3 27 0
# Error  3 28 0
# Error  3 29 0
# Error  3 30 0
# Error  4 0 0
# Error  4 2 0
# Error  4 3 0
# Error  4 4 0
# Error  4 5 0
# Error  4 6 0
# Error  4 7 0
# Error  4 8 0
# Error  4 9 0
# Error  4 10 0
# Error  4 11 0
# Error  4 12 0
# Error  4 13 0
# Error  4 14 0
# Error  4 15 0
# Error  4 16 0
# Error  4 17 0
# Error  4 18 0
# Error  4 19 0
# Error  4 20 0
# Error  4 21 0
# Error  4 22 0
# Error  4 23 0
# Error  4 24 0
# Error  4 25 0
# Error  4 26 0
# Error  4 27 0
# Error  4 28 0
# Error  4 29 0
# Error  4 30 0
# Error  5 0 0
# Error  5 2 0
# Error  5 3 0
# Error  5 4 0
# Error  5 5 0
# Error  5 6 0
# Error  5 7 0
# Error  5 8 0
# Error  5 9 0
# Error  5 10 0
# Error  5 11 0
# Error  5 12 0
# Error  5 13 0
# Error  5 14 0
# Error  5 15 0
# Error  5 16 0
# Error  5 17 0
# Error  5 18 0
# Error  5 19 0
# Error  5 20 0
# Error  5 21 0
# Error  5 22 0
# Error  5 23 0
# Error  5 24 0
# Error  5 25 0
# Error  5 26 0
# Error  5 27 0
# Error  5 28 0
# Error  5 29 0
# Error  5 30 0
# Error  6 0 0
# Error  6 2 0
# Error  6 3 0
# Error  6 4 0
# Error  6 5 0
# Error  6 6 0
# Error  6 7 0
# Error  6 8 0
# Error  6 9 0
# Error  6 10 0
# Error  6 11 0
# Error  6 12 0
# Error  6 13 0
# Error  6 14 0
# Error  6 15 0
# Error  6 16 0
# Error  6 17 0
# Error  6 18 0
# Error  6 19 0
# Error  6 20 0
# Error  6 21 0
# Error  6 22 0
# Error  6 23 0
# Error  6 24 0
# Error  6 25 0
# Error  6 26 0
# Error  6 27 0
# Error  6 28 0
# Error  6 29 0
# Error  6 30 0
# Error  7 0 0
# Error  7 2 0
# Error  7 3 0
# Error  7 4 0
# Error  7 5 0
# Error  7 6 0
# Error  7 7 0
# Error  7 8 0
# Error  7 9 0
# Error  7 10 0
# Error  7 11 0
# Error  7 12 0
# Error  7 13 0
# Error  7 14 0
# Error  7 15 0
# Error  7 16 0
# Error  7 17 0
# Error  7 18 0
# Error  7 19 0
# Error  7 20 0
# Error  7 21 0
# Error  7 22 0
# Error  7 23 0
# Error  7 24 0
# Error  7 25 0
# Error  7 26 0
# Error  7 27 0
# Error  7 28 0
# Error  7 29 0
# Error  7 30 0
# Error  8 0 0
# Error  8 2 0
# Error  8 3 0
# Error  8 4 0
# Error  8 5 0
# Error  8 6 0
# Error  8 7 0
# Error  8 8 0
# Error  8 9 0
# Error  8 10 0
# Error  8 11 0
# Error  8 12 0
# Error  8 13 0
# Error  8 14 0
# Error  8 15 0
# Error  8 16 0
# Error  8 17 0
# Error  8 18 0
# Error  8 19 0
# Error  8 20 0
# Error  8 21 0
# Error  8 22 0
# Error  8 23 0
# Error  8 24 0
# Error  8 25 0
# Error  8 26 0
# Error  8 27 0
# Error  8 28 0
# Error  8 29 0
# Error  8 30 0
# Error  9 0 0
# Error  9 2 0
# Error  9 3 0
# Error  9 4 0
# Error  9 5 0
# Error  9 6 0
# Error  9 7 0
# Error  9 8 0
# Error  9 9 0
# Error  9 10 0
# Error  9 11 0
# Error  9 12 0
# Error  9 13 0
# Error  9 14 0
# Error  9 15 0
# Error  9 16 0
# Error  9 17 0
# Error  9 18 0
# Error  9 19 0
# Error  9 20 0
# Error  9 21 0
# Error  9 22 0
# Error  9 23 0
# Error  9 24 0
# Error  9 25 0
# Error  9 26 0
# Error  9 27 0
# Error  9 28 0
# Error  9 29 0
# Error  9 30 0
# Error  10 0 0
# Error  10 2 0
# Error  10 3 0
# Error  10 4 0
# Error  10 5 0
# Error  10 6 0
# Error  10 7 0
# Error  10 8 0
# Error  10 9 0
# Error  10 10 0
# Error  10 11 0
# Error  10 12 0
# Error  10 13 0
# Error  10 14 0
# Error  10 15 0
# Error  10 16 0
# Error  10 17 0
# Error  10 18 0
# Error  10 19 0
# Error  10 20 0
# Error  10 21 0
# Error  10 22 0
# Error  10 23 0
# Error  10 24 0
# Error  10 25 0
# Error  10 26 0
# Error  10 27 0
# Error  10 28 0
# Error  10 29 0
# Error  10 30 0
# Error  11 0 0
# Error  11 2 0
# Error  11 3 0
# Error  11 4 0
# Error  11 5 0
# Error  11 6 0
# Error  11 7 0
# Error  11 8 0
# Error  11 9 0
# Error  11 10 0
# Error  11 11 0
# Error  11 12 0
# Error  11 13 0
# Error  11 14 0
# Error  11 15 0
# Error  11 16 0
# Error  11 17 0
# Error  11 18 0
# Error  11 19 0
# Error  11 20 0
# Error  11 21 0
# Error  11 22 0
# Error  11 23 0
# Error  11 24 0
# Error  11 25 0
# Error  11 26 0
# Error  11 27 0
# Error  11 28 0
# Error  11 29 0
# Error  11 30 0
# Error  12 0 0
# Error  12 2 0
# Error  12 3 0
# Error  12 4 0
# Error  12 5 0
# Error  12 6 0
# Error  12 7 0
# Error  12 8 0
# Error  12 9 0
# Error  12 10 0
# Error  12 11 0
# Error  12 12 0
# Error  12 13 0
# Error  12 14 0
# Error  12 15 0
# Error  12 16 0
# Error  12 17 0
# Error  12 18 0
# Error  12 19 0
# Error  12 20 0
# Error  12 21 0
# Error  12 22 0
# Error  12 23 0
# Error  12 24 0
# Error  12 25 0
# Error  12 26 0
# Error  12 27 0
# Error  12 28 0
# Error  12 29 0
# Error  12 30 0
# Error  13 0 0
# Error  13 2 0
# Error  13 3 0
# Error  13 4 0
# Error  13 5 0
# Error  13 6 0
# Error  13 7 0
# Error  13 8 0
# Error  13 9 0
# Error  13 10 0
# Error  13 11 0
# Error  13 12 0
# Error  13 13 0
# Error  13 14 0
# Error  13 15 0
# Error  13 16 0
# Error  13 17 0
# Error  13 18 0
# Error  13 19 0
# Error  13 20 0
# Error  13 21 0
# Error  13 22 0
# Error  13 23 0
# Error  13 24 0
# Error  13 25 0
# Error  13 26 0
# Error  13 27 0
# Error  13 28 0
# Error  13 29 0
# Error  13 30 0
# Error  14 0 0
# Error  14 2 0
# Error  14 3 0
# Error  14 4 0
# Error  14 5 0
# Error  14 6 0
# Error  14 7 0
# Error  14 8 0
# Error  14 9 0
# Error  14 10 0
# Error  14 11 0
# Error  14 12 0
# Error  14 13 0
# Error  14 14 0
# Error  14 15 0
# Error  14 16 0
# Error  14 17 0
# Error  14 18 0
# Error  14 19 0
# Error  14 20 0
# Error  14 21 0
# Error  14 22 0
# Error  14 23 0
# Error  14 24 0
# Error  14 25 0
# Error  14 26 0
# Error  14 27 0
# Error  14 28 0
# Error  14 29 0
# Error  14 30 0
# Error  15 0 0
# Error  15 2 0
# Error  15 3 0
# Error  15 4 0
# Error  15 5 0
# Error  15 6 0
# Error  15 7 0
# Error  15 8 0
# Error  15 9 0
# Error  15 10 0
# Error  15 11 0
# Error  15 12 0
# Error  15 13 0
# Error  15 14 0
# Error  15 15 0
# Error  15 16 0
# Error  15 17 0
# Error  15 18 0
# Error  15 19 0
# Error  15 20 0
# Error  15 21 0
# Error  15 22 0
# Error  15 23 0
# Error  15 24 0
# Error  15 25 0
# Error  15 26 0
# Error  15 27 0
# Error  15 28 0
# Error  15 29 0
# Error  15 30 0
# Error  16 0 0
# Error  16 2 0
# Error  16 3 0
# Error  16 4 0
# Error  16 5 0
# Error  16 6 0
# Error  16 7 0
# Error  16 8 0
# Error  16 9 0
# Error  16 10 0
# Error  16 11 0
# Error  16 12 0
# Error  16 13 0
# Error  16 14 0
# Error  16 15 0
# Error  16 16 0
# Error  16 17 0
# Error  16 18 0
# Error  16 19 0
# Error  16 20 0
# Error  16 21 0
# Error  16 22 0
# Error  16 23 0
# Error  16 24 0
# Error  16 25 0
# Error  16 26 0
# Error  16 27 0
# Error  16 28 0
# Error  16 29 0
# Error  16 30 0
# Error  17 0 0
# Error  17 2 0
# Error  17 3 0
# Error  17 4 0
# Error  17 5 0
# Error  17 6 0
# Error  17 7 0
# Error  17 8 0
# Error  17 9 0
# Error  17 10 0
# Error  17 11 0
# Error  17 12 0
# Error  17 13 0
# Error  17 14 0
# Error  17 15 0
# Error  17 16 0
# Error  17 17 0
# Error  17 18 0
# Error  17 19 0
# Error  17 20 0
# Error  17 21 0
# Error  17 22 0
# Error  17 23 0
# Error  17 24 0
# Error  17 25 0
# Error  17 26 0
# Error  17 27 0
# Error  17 28 0
# Error  17 29 0
# Error  17 30 0
# Error  18 0 0
# Error  18 2 0
# Error  18 3 0
# Error  18 4 0
# Error  18 5 0
# Error  18 6 0
# Error  18 7 0
# Error  18 8 0
# Error  18 9 0
# Error  18 10 0
# Error  18 11 0
# Error  18 12 0
# Error  18 13 0
# Error  18 14 0
# Error  18 15 0
# Error  18 16 0
# Error  18 17 0
# Error  18 18 0
# Error  18 19 0
# Error  18 20 0
# Error  18 21 0
# Error  18 22 0
# Error  18 23 0
# Error  18 24 0
# Error  18 25 0
# Error  18 26 0
# Error  18 27 0
# Error  18 28 0
# Error  18 29 0
# Error  18 30 0
# Error  19 0 0
# Error  19 2 0
# Error  19 3 0
# Error  19 4 0
# Error  19 5 0
# Error  19 6 0
# Error  19 7 0
# Error  19 8 0
# Error  19 9 0
# Error  19 10 0
# Error  19 11 0
# Error  19 12 0
# Error  19 13 0
# Error  19 14 0
# Error  19 15 0
# Error  19 16 0
# Error  19 17 0
# Error  19 18 0
# Error  19 19 0
# Error  19 20 0
# Error  19 21 0
# Error  19 22 0
# Error  19 23 0
# Error  19 24 0
# Error  19 25 0
# Error  19 26 0
# Error  19 27 0
# Error  19 28 0
# Error  19 29 0
# Error  19 30 0
# Error  20 0 0
# Error  20 2 0
# Error  20 3 0
# Error  20 4 0
# Error  20 5 0
# Error  20 6 0
# Error  20 7 0
# Error  20 8 0
# Error  20 9 0
# Error  20 10 0
# Error  20 11 0
# Error  20 12 0
# Error  20 13 0
# Error  20 14 0
# Error  20 15 0
# Error  20 16 0
# Error  20 17 0
# Error  20 18 0
# Error  20 19 0
# Error  20 20 0
# Error  20 21 0
# Error  20 22 0
# Error  20 23 0
# Error  20 24 0
# Error  20 25 0
# Error  20 26 0
# Error  20 27 0
# Error  20 28 0
# Error  20 29 0
# Error  20 30 0
# Error  21 0 0
# Error  21 2 0
# Error  21 3 0
# Error  21 4 0
# Error  21 5 0
# Error  21 6 0
# Error  21 7 0
# Error  21 8 0
# Error  21 9 0
# Error  21 10 0
# Error  21 11 0
# Error  21 12 0
# Error  21 13 0
# Error  21 14 0
# Error  21 15 0
# Error  21 16 0
# Error  21 17 0
# Error  21 18 0
# Error  21 19 0
# Error  21 20 0
# Error  21 21 0
# Error  21 22 0
# Error  21 23 0
# Error  21 24 0
# Error  21 25 0
# Error  21 26 0
# Error  21 27 0
# Error  21 28 0
# Error  21 29 0
# Error  21 30 0
# Error  22 0 0
# Error  22 2 0
# Error  22 3 0
# Error  22 4 0
# Error  22 5 0
# Error  22 6 0
# Error  22 7 0
# Error  22 8 0
# Error  22 9 0
# Error  22 10 0
# Error  22 11 0
# Error  22 12 0
# Error  22 13 0
# Error  22 14 0
# Error  22 15 0
# Error  22 16 0
# Error  22 17 0
# Error  22 18 0
# Error  22 19 0
# Error  22 20 0
# Error  22 21 0
# Error  22 22 0
# Error  22 23 0
# Error  22 24 0
# Error  22 25 0
# Error  22 26 0
# Error  22 27 0
# Error  22 28 0
# Error  22 29 0
# Error  22 30 0
# Error  23 0 0
# Error  23 2 0
# Error  23 3 0
# Error  23 4 0
# Error  23 5 0
# Error  23 6 0
# Error  23 7 0
# Error  23 8 0
# Error  23 9 0
# Error  23 10 0
# Error  23 11 0
# Error  23 12 0
# Error  23 13 0
# Error  23 14 0
# Error  23 15 0
# Error  23 16 0
# Error  23 17 0
# Error  23 18 0
# Error  23 19 0
# Error  23 20 0
# Error  23 21 0
# Error  23 22 0
# Error  23 23 0
# Error  23 24 0
# Error  23 25 0
# Error  23 26 0
# Error  23 27 0
# Error  23 28 0
# Error  23 29 0
# Error  23 30 0
# Error  24 0 0
# Error  24 2 0
# Error  24 3 0
# Error  24 4 0
# Error  24 5 0
# Error  24 6 0
# Error  24 7 0
# Error  24 8 0
# Error  24 9 0
# Error  24 10 0
# Error  24 11 0
# Error  24 12 0
# Error  24 13 0
# Error  24 14 0
# Error  24 15 0
# Error  24 16 0
# Error  24 17 0
# Error  24 18 0
# Error  24 19 0
# Error  24 20 0
# Error  24 21 0
# Error  24 22 0
# Error  24 23 0
# Error  24 24 0
# Error  24 25 0
# Error  24 26 0
# Error  24 27 0
# Error  24 28 0
# Error  24 29 0
# Error  24 30 0
# Error  25 0 0
# Error  25 2 0
# Error  25 3 0
# Error  25 4 0
# Error  25 5 0
# Error  25 6 0
# Error  25 7 0
# Error  25 8 0
# Error  25 9 0
# Error  25 10 0
# Error  25 11 0
# Error  25 12 0
# Error  25 13 0
# Error  25 14 0
# Error  25 15 0
# Error  25 16 0
# Error  25 17 0
# Error  25 18 0
# Error  25 19 0
# Error  25 20 0
# Error  25 21 0
# Error  25 22 0
# Error  25 23 0
# Error  25 24 0
# Error  25 25 0
# Error  25 26 0
# Error  25 27 0
# Error  25 28 0
# Error  25 29 0
# Error  25 30 0
# Error  26 0 0
# Error  26 2 0
# Error  26 3 0
# Error  26 4 0
# Error  26 5 0
# Error  26 6 0
# Error  26 7 0
# Error  26 8 0
# Error  26 9 0
# Error  26 10 0
# Error  26 11 0
# Error  26 12 0
# Error  26 13 0
# Error  26 14 0
# Error  26 15 0
# Error  26 16 0
# Error  26 17 0
# Error  26 18 0
# Error  26 19 0
# Error  26 20 0
# Error  26 21 0
# Error  26 22 0
# Error  26 23 0
# Error  26 24 0
# Error  26 25 0
# Error  26 26 0
# Error  26 27 0
# Error  26 28 0
# Error  26 29 0
# Error  26 30 0
# Error  27 0 0
# Error  27 2 0
# Error  27 3 0
# Error  27 4 0
# Error  27 5 0
# Error  27 6 0
# Error  27 7 0
# Error  27 8 0
# Error  27 9 0
# Error  27 10 0
# Error  27 11 0
# Error  27 12 0
# Error  27 13 0
# Error  27 14 0
# Error  27 15 0
# Error  27 16 0
# Error  27 17 0
# Error  27 18 0
# Error  27 19 0
# Error  27 20 0
# Error  27 21 0
# Error  27 22 0
# Error  27 23 0
# Error  27 24 0
# Error  27 25 0
# Error  27 26 0
# Error  27 27 0
# Error  27 28 0
# Error  27 29 0
# Error  27 30 0
# Error  28 0 0
# Error  28 2 0
# Error  28 3 0
# Error  28 4 0
# Error  28 5 0
# Error  28 6 0
# Error  28 7 0
# Error  28 8 0
# Error  28 9 0
# Error  28 10 0
# Error  28 11 0
# Error  28 12 0
# Error  28 13 0
# Error  28 14 0
# Error  28 15 0
# Error  28 16 0
# Error  28 17 0
# Error  28 18 0
# Error  28 19 0
# Error  28 20 0
# Error  28 21 0
# Error  28 22 0
# Error  28 23 0
# Error  28 24 0
# Error  28 25 0
# Error  28 26 0
# Error  28 27 0
# Error  28 28 0
# Error  28 29 0
# Error  28 30 0
# Error  29 0 0
# Error  29 2 0
# Error  29 3 0
# Error  29 4 0
# Error  29 5 0
# Error  29 6 0
# Error  29 7 0
# Error  29 8 0
# Error  29 9 0
# Error  29 10 0
# Error  29 11 0
# Error  29 12 0
# Error  29 13 0
# Error  29 14 0
# Error  29 15 0
# Error  29 16 0
# Error  29 17 0
# Error  29 18 0
# Error  29 19 0
# Error  29 20 0
# Error  29 21 0
# Error  29 22 0
# Error  29 23 0
# Error  29 24 0
# Error  29 25 0
# Error  29 26 0
# Error  29 27 0
# Error  29 28 0
# Error  29 29 0
# Error  29 30 0
# Error  30 0 0
# Error  30 2 0
# Error  30 3 0
# Error  30 4 0
# Error  30 5 0
# Error  30 6 0
# Error  30 7 0
# Error  30 8 0
# Error  30 9 0
# Error  30 10 0
# Error  30 11 0
# Error  30 12 0
# Error  30 13 0
# Error  30 14 0
# Error  30 15 0
# Error  30 16 0
# Error  30 17 0
# Error  30 18 0
# Error  30 19 0
# Error  30 20 0
# Error  30 21 0
# Error  30 22 0
# Error  30 23 0
# Error  30 24 0
# Error  30 25 0
# Error  30 26 0
# Error  30 27 0
# Error  30 28 0
# Error  30 29 0
# Error  30 30 0
# Error  31 0 0
# Error  31 2 0
# Error  31 3 0
# Error  31 4 0
# Error  31 5 0
# Error  31 6 0
# Error  31 7 0
# Error  31 8 0
# Error  31 9 0
# Error  31 10 0
# Error  31 11 0
# Error  31 12 0
# Error  31 13 0
# Error  31 14 0
# Error  31 15 0
# Error  31 16 0
# Error  31 17 0
# Error  31 18 0
# Error  31 19 0
# Error  31 20 0
# Error  31 21 0
# Error  31 22 0
# Error  31 23 0
# Error  31 24 0
# Error  31 25 0
# Error  31 26 0
# Error  31 27 0
# Error  31 28 0
# Error  31 29 0
# Error  31 30 0
# Error  32 0 0
# Error  32 2 0
# Error  32 3 0
# Error  32 4 0
# Error  32 5 0
# Error  32 6 0
# Error  32 7 0
# Error  32 8 0
# Error  32 9 0
# Error  32 10 0
# Error  32 11 0
# Error  32 12 0
# Error  32 13 0
# Error  32 14 0
# Error  32 15 0
# Error  32 16 0
# Error  32 17 0
# Error  32 18 0
# Error  32 19 0
# Error  32 20 0
# Error  32 21 0
# Error  32 22 0
# Error  32 23 0
# Error  32 24 0
# Error  32 25 0
# Error  32 26 0
# Error  32 27 0
# Error  32 28 0
# Error  32 29 0
# Error  32 30 0
# Error  33 0 0
# Error  33 2 0
# Error  33 3 0
# Error  33 4 0
# Error  33 5 0
# Error  33 6 0
# Error  33 7 0
# Error  33 8 0
# Error  33 9 0
# Error  33 10 0
# Error  33 11 0
# Error  33 12 0
# Error  33 13 0
# Error  33 14 0
# Error  33 15 0
# Error  33 16 0
# Error  33 17 0
# Error  33 18 0
# Error  33 19 0
# Error  33 20 0
# Error  33 21 0
# Error  33 22 0
#   3%|▎         | 1/31 [00:01<00:39,  1.33s/it]
# Error  33 23 0
# Error  33 24 0
# Error  33 25 0
# Error  33 26 0
# Error  33 27 0
# Error  33 28 0
# Error  33 29 0
# Error  33 30 0
# Error  34 0 0
# Error  34 2 0
# Error  34 3 0
# Error  34 4 0
# Error  34 5 0
# Error  34 6 0
# Error  34 7 0
# Error  34 8 0
# Error  34 9 0
# Error  34 10 0
# Error  34 11 0
# Error  34 12 0
# Error  34 13 0
# Error  34 14 0
# Error  34 15 0
# Error  34 16 0
# Error  34 17 0
# Error  34 18 0
# Error  34 19 0
# Error  34 20 0
# Error  34 21 0
# Error  34 22 0
# Error  34 23 0
# Error  34 24 0
# Error  34 25 0
# Error  34 26 0
# Error  34 27 0
# Error  34 28 0
# Error  34 29 0
# Error  34 30 0
# 100%|██████████| 31/31 [00:19<00:00,  1.59it/s]
#   0%|          | 0/31 [00:00<?, ?it/s]
# Error  2 0 0
# Error  2 2 0
# Error  2 3 0
# Error  2 4 0
# Error  2 5 0
# Error  2 6 0
# Error  2 7 0
# Error  2 8 0
# Error  2 9 0
# Error  2 10 0
# Error  2 11 0
# Error  2 12 0
# Error  2 13 0
# Error  2 14 0
# Error  2 15 0
# Error  2 16 0
# Error  2 17 0
# Error  2 18 0
# Error  2 19 0
# Error  2 20 0
# Error  2 21 0
# Error  2 22 0
# Error  2 23 0
# Error  2 24 0
# Error  2 25 0
# Error  2 26 0
# Error  2 27 0
# Error  2 28 0
# Error  2 29 0
# Error  2 30 0
# Error  3 0 0
# Error  3 2 0
# Error  3 3 0
# Error  3 4 0
# Error  3 5 0
# Error  3 6 0
# Error  3 7 0
# Error  3 8 0
# Error  3 9 0
# Error  3 10 0
# Error  3 11 0
# Error  3 12 0
# Error  3 13 0
# Error  3 14 0
# Error  3 15 0
# Error  3 16 0
# Error  3 17 0
# Error  3 18 0
# Error  3 19 0
# Error  3 20 0
# Error  3 21 0
# Error  3 22 0
# Error  3 23 0
# Error  3 24 0
# Error  3 25 0
# Error  3 26 0
# Error  3 27 0
# Error  3 28 0
# Error  3 29 0
# Error  3 30 0
# Error  4 0 0
# Error  4 2 0
# Error  4 3 0
# Error  4 4 0
# Error  4 5 0
# Error  4 6 0
# Error  4 7 0
# Error  4 8 0
# Error  4 9 0
# Error  4 10 0
# Error  4 11 0
# Error  4 12 0
# Error  4 13 0
# Error  4 14 0
# Error  4 15 0
# Error  4 16 0
# Error  4 17 0
# Error  4 18 0
# Error  4 19 0
# Error  4 20 0
# Error  4 21 0
# Error  4 22 0
# Error  4 23 0
# Error  4 24 0
# Error  4 25 0
# Error  4 26 0
# Error  4 27 0
# Error  4 28 0
# Error  4 29 0
# Error  4 30 0
# Error  5 0 0
# Error  5 2 0
# Error  5 3 0
# Error  5 4 0
# Error  5 5 0
# Error  5 6 0
# Error  5 7 0
# Error  5 8 0
# Error  5 9 0
# Error  5 10 0
# Error  5 11 0
# Error  5 12 0
# Error  5 13 0
# Error  5 14 0
# Error  5 15 0
# Error  5 16 0
# Error  5 17 0
# Error  5 18 0
# Error  5 19 0
# Error  5 20 0
# Error  5 21 0
# Error  5 22 0
# Error  5 23 0
# Error  5 24 0
# Error  5 25 0
# Error  5 26 0
# Error  5 27 0
# Error  5 28 0
# Error  5 29 0
# Error  5 30 0
# Error  6 0 0
# Error  6 2 0
# Error  6 3 0
# Error  6 4 0
# Error  6 5 0
# Error  6 6 0
# Error  6 7 0
# Error  6 8 0
# Error  6 9 0
# Error  6 10 0
# Error  6 11 0
# Error  6 12 0
# Error  6 13 0
# Error  6 14 0
# Error  6 15 0
# Error  6 16 0
# Error  6 17 0
# Error  6 18 0
# Error  6 19 0
# Error  6 20 0
# Error  6 21 0
# Error  6 22 0
# Error  6 23 0
# Error  6 24 0
# Error  6 25 0
# Error  6 26 0
# Error  6 27 0
# Error  6 28 0
# Error  6 29 0
# Error  6 30 0
# Error  7 0 0
# Error  7 2 0
# Error  7 3 0
# Error  7 4 0
# Error  7 5 0
# Error  7 6 0
# Error  7 7 0
# Error  7 8 0
# Error  7 9 0
# Error  7 10 0
# Error  7 11 0
# Error  7 12 0
# Error  7 13 0
# Error  7 14 0
# Error  7 15 0
# Error  7 16 0
# Error  7 17 0
# Error  7 18 0
# Error  7 19 0
# Error  7 20 0
# Error  7 21 0
# Error  7 22 0
# Error  7 23 0
# Error  7 24 0
# Error  7 25 0
# Error  7 26 0
# Error  7 27 0
# Error  7 28 0
# Error  7 29 0
# Error  7 30 0
# Error  8 0 0
# Error  8 2 0
# Error  8 3 0
# Error  8 4 0
# Error  8 5 0
# Error  8 6 0
# Error  8 7 0
# Error  8 8 0
# Error  8 9 0
# Error  8 10 0
# Error  8 11 0
# Error  8 12 0
# Error  8 13 0
# Error  8 14 0
# Error  8 15 0
# Error  8 16 0
# Error  8 17 0
# Error  8 18 0
# Error  8 19 0
# Error  8 20 0
# Error  8 21 0
# Error  8 22 0
# Error  8 23 0
# Error  8 24 0
# Error  8 25 0
# Error  8 26 0
# Error  8 27 0
# Error  8 28 0
# Error  8 29 0
# Error  8 30 0
# Error  9 0 0
# Error  9 2 0
# Error  9 3 0
# Error  9 4 0
# Error  9 5 0
# Error  9 6 0
# Error  9 7 0
# Error  9 8 0
# Error  9 9 0
# Error  9 10 0
# Error  9 11 0
# Error  9 12 0
# Error  9 13 0
# Error  9 14 0
# Error  9 15 0
# Error  9 16 0
# Error  9 17 0
# Error  9 18 0
# Error  9 19 0
# Error  9 20 0
# Error  9 21 0
# Error  9 22 0
# Error  9 23 0
# Error  9 24 0
# Error  9 25 0
# Error  9 26 0
# Error  9 27 0
# Error  9 28 0
# Error  9 29 0
# Error  9 30 0
# Error  10 0 0
# Error  10 2 0
# Error  10 3 0
# Error  10 4 0
# Error  10 5 0
# Error  10 6 0
# Error  10 7 0
# Error  10 8 0
# Error  10 9 0
# Error  10 10 0
# Error  10 11 0
# Error  10 12 0
# Error  10 13 0
# Error  10 14 0
# Error  10 15 0
# Error  10 16 0
# Error  10 17 0
# Error  10 18 0
# Error  10 19 0
# Error  10 20 0
# Error  10 21 0
# Error  10 22 0
# Error  10 23 0
# Error  10 24 0
# Error  10 25 0
# Error  10 26 0
# Error  10 27 0
# Error  10 28 0
# Error  10 29 0
# Error  10 30 0
# Error  11 0 0
# Error  11 2 0
# Error  11 3 0
# Error  11 4 0
# Error  11 5 0
# Error  11 6 0
# Error  11 7 0
# Error  11 8 0
# Error  11 9 0
# Error  11 10 0
# Error  11 11 0
# Error  11 12 0
# Error  11 13 0
# Error  11 14 0
# Error  11 15 0
# Error  11 16 0
# Error  11 17 0
# Error  11 18 0
# Error  11 19 0
# Error  11 20 0
# Error  11 21 0
# Error  11 22 0
# Error  11 23 0
# Error  11 24 0
# Error  11 25 0
# Error  11 26 0
# Error  11 27 0
# Error  11 28 0
# Error  11 29 0
# Error  11 30 0
# Error  12 0 0
# Error  12 2 0
# Error  12 3 0
# Error  12 4 0
# Error  12 5 0
# Error  12 6 0
# Error  12 7 0
# Error  12 8 0
# Error  12 9 0
# Error  12 10 0
# Error  12 11 0
# Error  12 12 0
# Error  12 13 0
# Error  12 14 0
# Error  12 15 0
# Error  12 16 0
# Error  12 17 0
# Error  12 18 0
# Error  12 19 0
# Error  12 20 0
# Error  12 21 0
# Error  12 22 0
# Error  12 23 0
# Error  12 24 0
# Error  12 25 0
# Error  12 26 0
# Error  12 27 0
# Error  12 28 0
# Error  12 29 0
# Error  12 30 0
# Error  13 0 0
# Error  13 2 0
# Error  13 3 0
# Error  13 4 0
# Error  13 5 0
# Error  13 6 0
# Error  13 7 0
# Error  13 8 0
# Error  13 9 0
# Error  13 10 0
# Error  13 11 0
# Error  13 12 0
# Error  13 13 0
# Error  13 14 0
# Error  13 15 0
# Error  13 16 0
# Error  13 17 0
# Error  13 18 0
# Error  13 19 0
# Error  13 20 0
# Error  13 21 0
# Error  13 22 0
# Error  13 23 0
# Error  13 24 0
# Error  13 25 0
# Error  13 26 0
# Error  13 27 0
# Error  13 28 0
# Error  13 29 0
# Error  13 30 0
# Error  14 0 0
# Error  14 2 0
# Error  14 3 0
# Error  14 4 0
# Error  14 5 0
# Error  14 6 0
# Error  14 7 0
# Error  14 8 0
# Error  14 9 0
# Error  14 10 0
# Error  14 11 0
# Error  14 12 0
# Error  14 13 0
# Error  14 14 0
# Error  14 15 0
# Error  14 16 0
# Error  14 17 0
# Error  14 18 0
# Error  14 19 0
# Error  14 20 0
# Error  14 21 0
# Error  14 22 0
# Error  14 23 0
# Error  14 24 0
# Error  14 25 0
# Error  14 26 0
# Error  14 27 0
# Error  14 28 0
# Error  14 29 0
# Error  14 30 0
# Error  15 0 0
# Error  15 2 0
# Error  15 3 0
# Error  15 4 0
# Error  15 5 0
# Error  15 6 0
# Error  15 7 0
# Error  15 8 0
# Error  15 9 0
# Error  15 10 0
# Error  15 11 0
# Error  15 12 0
# Error  15 13 0
# Error  15 14 0
# Error  15 15 0
# Error  15 16 0
# Error  15 17 0
# Error  15 18 0
# Error  15 19 0
# Error  15 20 0
# Error  15 21 0
# Error  15 22 0
# Error  15 23 0
# Error  15 24 0
# Error  15 25 0
# Error  15 26 0
# Error  15 27 0
# Error  15 28 0
# Error  15 29 0
# Error  15 30 0
# Error  16 0 0
# Error  16 2 0
# Error  16 3 0
# Error  16 4 0
# Error  16 5 0
# Error  16 6 0
# Error  16 7 0
# Error  16 8 0
# Error  16 9 0
# Error  16 10 0
# Error  16 11 0
# Error  16 12 0
# Error  16 13 0
# Error  16 14 0
# Error  16 15 0
# Error  16 16 0
# Error  16 17 0
# Error  16 18 0
# Error  16 19 0
# Error  16 20 0
# Error  16 21 0
# Error  16 22 0
# Error  16 23 0
# Error  16 24 0
# Error  16 25 0
# Error  16 26 0
# Error  16 27 0
# Error  16 28 0
# Error  16 29 0
# Error  16 30 0
# Error  17 0 0
# Error  17 2 0
# Error  17 3 0
# Error  17 4 0
# Error  17 5 0
# Error  17 6 0
# Error  17 7 0
# Error  17 8 0
# Error  17 9 0
# Error  17 10 0
# Error  17 11 0
# Error  17 12 0
# Error  17 13 0
# Error  17 14 0
# Error  17 15 0
# Error  17 16 0
# Error  17 17 0
# Error  17 18 0
# Error  17 19 0
# Error  17 20 0
# Error  17 21 0
# Error  17 22 0
# Error  17 23 0
# Error  17 24 0
# Error  17 25 0
# Error  17 26 0
# Error  17 27 0
# Error  17 28 0
# Error  17 29 0
# Error  17 30 0
# Error  18 0 0
# Error  18 2 0
# Error  18 3 0
# Error  18 4 0
# Error  18 5 0
# Error  18 6 0
# Error  18 7 0
# Error  18 8 0
# Error  18 9 0
# Error  18 10 0
# Error  18 11 0
# Error  18 12 0
# Error  18 13 0
# Error  18 14 0
# Error  18 15 0
# Error  18 16 0
# Error  18 17 0
# Error  18 18 0
# Error  18 19 0
# Error  18 20 0
# Error  18 21 0
# Error  18 22 0
# Error  18 23 0
# Error  18 24 0
# Error  18 25 0
# Error  18 26 0
# Error  18 27 0
# Error  18 28 0
# Error  18 29 0
# Error  18 30 0
# Error  19 0 0
# Error  19 2 0
# Error  19 3 0
# Error  19 4 0
# Error  19 5 0
# Error  19 6 0
# Error  19 7 0
# Error  19 8 0
# Error  19 9 0
# Error  19 10 0
# Error  19 11 0
# Error  19 12 0
# Error  19 13 0
# Error  19 14 0
# Error  19 15 0
# Error  19 16 0
# Error  19 17 0
# Error  19 18 0
# Error  19 19 0
# Error  19 20 0
# Error  19 21 0
# Error  19 22 0
# Error  19 23 0
# Error  19 24 0
# Error  19 25 0
# Error  19 26 0
# Error  19 27 0
# Error  19 28 0
# Error  19 29 0
# Error  19 30 0
# Error  20 0 0
# Error  20 2 0
# Error  20 3 0
# Error  20 4 0
# Error  20 5 0
# Error  20 6 0
# Error  20 7 0
# Error  20 8 0
# Error  20 9 0
# Error  20 10 0
# Error  20 11 0
# Error  20 12 0
# Error  20 13 0
# Error  20 14 0
# Error  20 15 0
# Error  20 16 0
# Error  20 17 0
# Error  20 18 0
# Error  20 19 0
# Error  20 20 0
# Error  20 21 0
# Error  20 22 0
# Error  20 23 0
# Error  20 24 0
# Error  20 25 0
# Error  20 26 0
# Error  20 27 0
# Error  20 28 0
# Error  20 29 0
# Error  20 30 0
# Error  21 0 0
# Error  21 2 0
# Error  21 3 0
# Error  21 4 0
# Error  21 5 0
# Error  21 6 0
# Error  21 7 0
# Error  21 8 0
# Error  21 9 0
# Error  21 10 0
# Error  21 11 0
# Error  21 12 0
# Error  21 13 0
# Error  21 14 0
# Error  21 15 0
# Error  21 16 0
# Error  21 17 0
# Error  21 18 0
# Error  21 19 0
# Error  21 20 0
# Error  21 21 0
# Error  21 22 0
# Error  21 23 0
# Error  21 24 0
# Error  21 25 0
# Error  21 26 0
# Error  21 27 0
# Error  21 28 0
# Error  21 29 0
# Error  21 30 0
# Error  22 0 0
# Error  22 2 0
# Error  22 3 0
# Error  22 4 0
# Error  22 5 0
# Error  22 6 0
# Error  22 7 0
# Error  22 8 0
# Error  22 9 0
# Error  22 10 0
# Error  22 11 0
# Error  22 12 0
# Error  22 13 0
# Error  22 14 0
# Error  22 15 0
# Error  22 16 0
# Error  22 17 0
# Error  22 18 0
# Error  22 19 0
# Error  22 20 0
# Error  22 21 0
# Error  22 22 0
# Error  22 23 0
# Error  22 24 0
# Error  22 25 0
# Error  22 26 0
# Error  22 27 0
# Error  22 28 0
# Error  22 29 0
# Error  22 30 0
# Error  23 0 0
# Error  23 2 0
# Error  23 3 0
# Error  23 4 0
# Error  23 5 0
# Error  23 6 0
# Error  23 7 0
# Error  23 8 0
# Error  23 9 0
# Error  23 10 0
# Error  23 11 0
# Error  23 12 0
# Error  23 13 0
# Error  23 14 0
# Error  23 15 0
# Error  23 16 0
# Error  23 17 0
# Error  23 18 0
# Error  23 19 0
# Error  23 20 0
# Error  23 21 0
# Error  23 22 0
# Error  23 23 0
# Error  23 24 0
# Error  23 25 0
# Error  23 26 0
# Error  23 27 0
# Error  23 28 0
# Error  23 29 0
# Error  23 30 0
# Error  24 0 0
# Error  24 2 0
# Error  24 3 0
# Error  24 4 0
# Error  24 5 0
# Error  24 6 0
# Error  24 7 0
# Error  24 8 0
# Error  24 9 0
# Error  24 10 0
# Error  24 11 0
# Error  24 12 0
# Error  24 13 0
# Error  24 14 0
# Error  24 15 0
# Error  24 16 0
# Error  24 17 0
# Error  24 18 0
# Error  24 19 0
# Error  24 20 0
# Error  24 21 0
# Error  24 22 0
# Error  24 23 0
# Error  24 24 0
# Error  24 25 0
# Error  24 26 0
# Error  24 27 0
# Error  24 28 0
# Error  24 29 0
# Error  24 30 0
# Error  25 0 0
# Error  25 2 0
# Error  25 3 0
# Error  25 4 0
# Error  25 5 0
# Error  25 6 0
# Error  25 7 0
# Error  25 8 0
# Error  25 9 0
# Error  25 10 0
# Error  25 11 0
# Error  25 12 0
# Error  25 13 0
# Error  25 14 0
# Error  25 15 0
# Error  25 16 0
# Error  25 17 0
# Error  25 18 0
# Error  25 19 0
# Error  25 20 0
# Error  25 21 0
# Error  25 22 0
# Error  25 23 0
# Error  25 24 0
# Error  25 25 0
# Error  25 26 0
# Error  25 27 0
# Error  25 28 0
# Error  25 29 0
# Error  25 30 0
# Error  26 0 0
# Error  26 2 0
# Error  26 3 0
# Error  26 4 0
# Error  26 5 0
# Error  26 6 0
# Error  26 7 0
# Error  26 8 0
# Error  26 9 0
# Error  26 10 0
# Error  26 11 0
# Error  26 12 0
# Error  26 13 0
# Error  26 14 0
# Error  26 15 0
# Error  26 16 0
# Error  26 17 0
# Error  26 18 0
# Error  26 19 0
# Error  26 20 0
# Error  26 21 0
# Error  26 22 0
# Error  26 23 0
# Error  26 24 0
# Error  26 25 0
# Error  26 26 0
# Error  26 27 0
# Error  26 28 0
# Error  26 29 0
# Error  26 30 0
# Error  27 0 0
# Error  27 2 0
# Error  27 3 0
# Error  27 4 0
# Error  27 5 0
# Error  27 6 0
# Error  27 7 0
# Error  27 8 0
# Error  27 9 0
# Error  27 10 0
# Error  27 11 0
# Error  27 12 0
# Error  27 13 0
# Error  27 14 0
# Error  27 15 0
# Error  27 16 0
# Error  27 17 0
# Error  27 18 0
# Error  27 19 0
# Error  27 20 0
# Error  27 21 0
# Error  27 22 0
# Error  27 23 0
# Error  27 24 0
# Error  27 25 0
# Error  27 26 0
# Error  27 27 0
# Error  27 28 0
# Error  27 29 0
# Error  27 30 0
# Error  28 0 0
# Error  28 2 0
# Error  28 3 0
# Error  28 4 0
# Error  28 5 0
# Error  28 6 0
# Error  28 7 0
# Error  28 8 0
# Error  28 9 0
# Error  28 10 0
# Error  28 11 0
# Error  28 12 0
# Error  28 13 0
# Error  28 14 0
# Error  28 15 0
# Error  28 16 0
# Error  28 17 0
# Error  28 18 0
# Error  28 19 0
# Error  28 20 0
# Error  28 21 0
# Error  28 22 0
# Error  28 23 0
# Error  28 24 0
# Error  28 25 0
# Error  28 26 0
# Error  28 27 0
# Error  28 28 0
# Error  28 29 0
# Error  28 30 0
# Error  29 0 0
# Error  29 2 0
# Error  29 3 0
# Error  29 4 0
# Error  29 5 0
# Error  29 6 0
# Error  29 7 0
# Error  29 8 0
# Error  29 9 0
# Error  29 10 0
# Error  29 11 0
# Error  29 12 0
# Error  29 13 0
# Error  29 14 0
# Error  29 15 0
# Error  29 16 0
# Error  29 17 0
# Error  29 18 0
# Error  29 19 0
# Error  29 20 0
# Error  29 21 0
# Error  29 22 0
# Error  29 23 0
# Error  29 24 0
# Error  29 25 0
# Error  29 26 0
# Error  29 27 0
# Error  29 28 0
# Error  29 29 0
# Error  29 30 0
# Error  30 0 0
# Error  30 2 0
# Error  30 3 0
# Error  30 4 0
# Error  30 5 0
# Error  30 6 0
# Error  30 7 0
# Error  30 8 0
# Error  30 9 0
# Error  30 10 0
# Error  30 11 0
# Error  30 12 0
# Error  30 13 0
# Error  30 14 0
# Error  30 15 0
# Error  30 16 0
# Error  30 17 0
# Error  30 18 0
# Error  30 19 0
# Error  30 20 0
# Error  30 21 0
# Error  30 22 0
# Error  30 23 0
# Error  30 24 0
# Error  30 25 0
# Error  30 26 0
# Error  30 27 0
# Error  30 28 0
# Error  30 29 0
# Error  30 30 0
# Error  31 0 0
# Error  31 2 0
# Error  31 3 0
# Error  31 4 0
# Error  31 5 0
# Error  31 6 0
# Error  31 7 0
# Error  31 8 0
# Error  31 9 0
# Error  31 10 0
# Error  31 11 0
# Error  31 12 0
# Error  31 13 0
# Error  31 14 0
# Error  31 15 0
# Error  31 16 0
# Error  31 17 0
# Error  31 18 0
# Error  31 19 0
# Error  31 20 0
# Error  31 21 0
# Error  31 22 0
# Error  31 23 0
# Error  31 24 0
# Error  31 25 0
# Error  31 26 0
# Error  31 27 0
# Error  31 28 0
# Error  31 29 0
# Error  31 30 0
# Error  32 0 0
# Error  32 2 0
# Error  32 3 0
# Error  32 4 0
# Error  32 5 0
# Error  32 6 0
# Error  32 7 0
# Error  32 8 0
# Error  32 9 0
# Error  32 10 0
# Error  32 11 0
# Error  32 12 0
# Error  32 13 0
# Error  32 14 0
# Error  32 15 0
#   3%|▎         | 1/31 [00:01<00:39,  1.31s/it]
# Error  32 16 0
# Error  32 17 0
# Error  32 18 0
# Error  32 19 0
# Error  32 20 0
# Error  32 21 0
# Error  32 22 0
# Error  32 23 0
# Error  32 24 0
# Error  32 25 0
# Error  32 26 0
# Error  32 27 0
# Error  32 28 0
# Error  32 29 0
# Error  32 30 0
# Error  33 0 0
# Error  33 2 0
# Error  33 3 0
# Error  33 4 0
# Error  33 5 0
# Error  33 6 0
# Error  33 7 0
# Error  33 8 0
# Error  33 9 0
# Error  33 10 0
# Error  33 11 0
# Error  33 12 0
# Error  33 13 0
# Error  33 14 0
# Error  33 15 0
# Error  33 16 0
# Error  33 17 0
# Error  33 18 0
# Error  33 19 0
# Error  33 20 0
# Error  33 21 0
# Error  33 22 0
# Error  33 23 0
# Error  33 24 0
# Error  33 25 0
# Error  33 26 0
# Error  33 27 0
# Error  33 28 0
# Error  33 29 0
# Error  33 30 0
# Error  34 0 0
# Error  34 2 0
# Error  34 3 0
# Error  34 4 0
# Error  34 5 0
# Error  34 6 0
# Error  34 7 0
# Error  34 8 0
# Error  34 9 0
# Error  34 10 0
# Error  34 11 0
# Error  34 12 0
# Error  34 13 0
# Error  34 14 0
# Error  34 15 0
# Error  34 16 0
# Error  34 17 0
# Error  34 18 0
# Error  34 19 0
# Error  34 20 0
# Error  34 21 0
# Error  34 22 0
# Error  34 23 0
# Error  34 24 0
# Error  34 25 0
# Error  34 26 0
# Error  34 27 0
# Error  34 28 0
# Error  34 29 0
# Error  34 30 0
# 100%|██████████| 31/31 [00:19<00:00,  1.57it/s]

# %%
4.*(huuCircASAAB0[0] - huuCircASAAB4[0])/3 - 4*huuDeltaRG[0]
# Out:
# array([[-2.22119904e-02-9.19714250e-18j, -1.76587386e-02-3.92379476e-18j],
#        [ 5.05720058e-01+0.00000000e+00j, -8.60255495e-01+0.00000000e+00j],
#        [-1.09394016e-04+0.00000000e+00j, -1.70757884e+00+0.00000000e+00j],
#        [ 6.08868771e-01+0.00000000e+00j, -2.57840752e+00+0.00000000e+00j],
#        [ 8.59368212e-01+0.00000000e+00j, -2.66228751e+00+0.00000000e+00j],
#        [ 1.50071374e+00+0.00000000e+00j, -3.50786329e+00+0.00000000e+00j],
#        [ 1.73503315e+00+0.00000000e+00j, -3.60614470e+00+0.00000000e+00j],
#        [ 2.40708358e+00+0.00000000e+00j, -4.42279419e+00+0.00000000e+00j],
#        [ 2.62689850e+00+0.00000000e+00j, -4.53488531e+00+0.00000000e+00j],
#        [ 3.31594139e+00+0.00000000e+00j, -5.33523711e+00+0.00000000e+00j],
#        [ 3.52597993e+00+0.00000000e+00j, -5.45676419e+00+0.00000000e+00j],
#        [ 4.22566936e+00+0.00000000e+00j, -6.24680988e+00+0.00000000e+00j],
#        [ 4.42882222e+00+0.00000000e+00j, -6.37503113e+00+0.00000000e+00j],
#        [ 5.13578237e+00+0.00000000e+00j, -7.15799761e+00+0.00000000e+00j],
#        [ 5.33385776e+00+0.00000000e+00j, -7.29117811e+00+0.00000000e+00j],
#        [ 6.04609212e+00+0.00000000e+00j, -8.06898860e+00+0.00000000e+00j],
#        [ 6.24028002e+00+0.00000000e+00j, -8.20597855e+00+0.00000000e+00j],
#        [ 6.95651294e+00+0.00000000e+00j, -8.97986852e+00+0.00000000e+00j],
#        [ 7.14763344e+00+0.00000000e+00j, -9.11987167e+00+0.00000000e+00j],
#        [ 7.86700123e+00+0.00000000e+00j, -9.89068096e+00+0.00000000e+00j],
#        [ 8.05564176e+00+0.00000000e+00j, -1.00331249e+01+0.00000000e+00j],
#        [ 8.77753290e+00+0.00000000e+00j, -1.08014500e+01+0.00000000e+00j],
#        [ 8.96412795e+00+0.00000000e+00j, -1.09459103e+01+0.00000000e+00j],
#        [ 9.68809372e+00+0.00000000e+00j, -1.17121900e+01+0.00000000e+00j],
#        [ 9.87297337e+00+0.00000000e+00j, -1.18583432e+01+0.00000000e+00j],
#        [ 1.05986749e+01+0.00000000e+00j, -1.26229095e+01+0.00000000e+00j],
#        [ 1.07820956e+01+0.00000000e+00j, -1.27705043e+01+0.00000000e+00j],
#        [ 1.15092706e+01+0.00000000e+00j, -1.35336145e+01+0.00000000e+00j],
#        [ 1.16914356e+01+0.00000000e+00j, -1.36824511e+01+0.00000000e+00j],
#        [ 1.24198771e+01+0.00000000e+00j, -1.44443087e+01+0.00000000e+00j],
#        [ 1.26009499e+01+0.00000000e+00j, -1.45942262e+01+0.00000000e+00j]])

# %%
np.real(np.sum(8.*huuCirc[1][5, :]/3 + 0.5*huuDeltaRG[:, 0], axis = 0))
# Out:
# array([0.06490372, 0.06490372])

# %%
np.real(np.sum(0.5*huuDeltaRG[:, 0], axis = 0))
# Out:
# array([0.06713386, 0.06713386])

# %%
lmodes = np.arange(1., lmax+1)
huuregB = orbit_average(huu_reg(geoCirc), geoCirc)
huul = 4*huuCirc[0][:lmax+1]
data = huul
datareg = huul - huuregB
ymin = np.min(np.abs(datareg[1:]))/5
ymax = 5*np.max(np.abs(datareg[1:]))
# ymin = np.min(np.abs(data[1:]))/5
# ymax = 5*np.max(np.abs(data[1:]))
plt.loglog(lmodes, np.abs(data[1:, 1]), label = '$h_{uu}^l$')
plt.loglog(lmodes, np.abs(datareg[1:, 1]), label = '$h_{uu}^l - \Phi^S_{[0]}$')
for i in range(20):
    plt.loglog(lmodes, ymax*10.**(2-0.5*i)*lmodes**(-2), '--', color='gray')
plt.ylim(ymin, ymax)
plt.xlim(1, lmax)
plt.xlabel("$l$")
plt.ylabel("$|h_{uu}^{R,l}|$")
plt.legend()
plt.show()

# %%
def lbasis(lmax):
    return [1., ((lmax + 1)), ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3)), ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3)/(2*lmax - 1)/(2*lmax + 5))]

# def lbasis(lmax):
#     return [1., ((lmax + 1)), ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3))]

# def lbasis(lmax):
#     return [1., ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3)), ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3)/(2*lmax - 1)/(2*lmax + 5))]

lminTest = 20
lmaxTest = lmax
ysum = np.array([np.sum(huul[:lmax + 1, 1]) for lmax in range(lminTest, lmaxTest + 1)])
xsum = np.array([lbasis(lmax) for lmax in range(lminTest, lmaxTest + 1)])

b = lsq_linear(xsum, ysum)
print(b)
# Out:
#  active_mask: array([0., 0., 0., 0.])
#         cost: 1.3409460390299635e-22
#          fun: array([ 5.24869037e-12, -8.11617440e-12, -4.13979961e-12,  2.41939802e-12,
#         5.75894887e-12,  4.82547335e-12,  9.41469125e-13, -3.51629836e-12,
#        -5.87441207e-12, -3.50297569e-12,  5.94102545e-12])
#      message: 'The unconstrained solution is optimal.'
#          nit: 0
#   optimality: 3.5926817076870066e-13
#       status: 3
#      success: True
#            x: array([-0.42095928,  0.19337977,  0.24225796,  0.19191467])

# %%
print(b.x[1] - huuregB)
hcomp =  completion(geoCirc)
zval = 0.5*(b.x[0] + hcomp)*Tr_ecc_geo_ratio(geoCirc)
if geoCirc.blackholespin == 0.:
    mval = -0.12912227
else:
    mval = -0.1201650349
zval, 1-zval/mval
# Out:
# 6.763878623861075e-10
# (-0.12912230751979664, -2.9057572037416435e-07)

# %% [markdown]
# ## Eccentric Test

# %%
geoEcc = KerrGeodesic(0.5, 10., 0.1, 1.0, 2**6)
huuData0 = redshift_calc_ecc('IRG', 30, geoEcc, nrange = [-10, 10])
# Out:
# 100%|██████████| 31/31 [26:38<00:00, 51.56s/it]

# %%
geoEcc2 = KerrGeodesic(0.5, 10., 0.1, 1.0, 2**7)
huuData2 = redshift_calc_ecc('IRG', 30, geoEcc2, nrange = [-10, 10])
# Out:
# 100%|██████████| 31/31 [45:33<00:00, 88.19s/it]

# %%
geoEcc3 = KerrGeodesic(0.5, 10., 0.1, 1.0, 2**6)
huuData3 = redshift_calc_ecc('IRG', 30, geoEcc3, nrange = [-14, 14])
# Out:
# 100%|██████████| 31/31 [48:07<00:00, 93.14s/it]

# %%
geoEcc3 = KerrGeodesic(0.25, 10., 0.1, 1.0, 2**6)
huuData3 = redshift_calc_ecc('IRG', 30, geoEcc3, nrange = [-14, 14])

# %%
huuDataTest = huuData3
lmax = huuDataTest[0].shape[0] - 1
lmodes = np.arange(1., lmax+1)
huuregB = orbit_average(huu_reg(geoEcc), geoEcc)
huul = orbit_average(huuDataTest[0], geoEcc, axis = 2)
datareg = huul - huuregB
ymin = np.min(np.abs(datareg[1:lmax + 1]))/5
ymax = 5*np.max(np.abs(datareg[1:lmax +1]))
plt.loglog(lmodes, np.abs(datareg[1:lmax + 1]))
for i in range(20):
    plt.loglog(lmodes, ymax*10.**(2-0.5*i)*lmodes**(-2), '--', color='gray')
plt.ylim(ymin, ymax)
plt.xlim(1, lmax)
plt.xlabel("$l$")
plt.ylabel("$|h_{uu}^l - B_0|$")
plt.show()

# %%
from scipy.optimize import lsq_linear
def lbasis(lmax):
    return [1., ((lmax + 1)), ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3)), ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3)/(2*lmax - 1)/(2*lmax + 5))]

# def lbasis(lmax):
#     return [1., ((lmax + 1)), ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3))]

# def lbasis(lmax):
#     return [1., ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3)), ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3)/(2*lmax - 1)/(2*lmax + 5))]

lminTest = 10
lmaxTest = lmax
ysum = np.array([np.sum(huul[:lmax + 1, 1]) for lmax in range(lminTest, lmaxTest + 1)])
xsum = np.array([lbasis(lmax) for lmax in range(lminTest, lmaxTest + 1)])

b = lsq_linear(xsum, ysum)
print(b)
# Out:
#        message: The unconstrained solution is optimal.
#        success: True
#         status: 3
#            fun: [ 2.944e-09 -2.550e-09 ...  4.646e-10  6.583e-09]
#              x: [-4.097e-01  1.921e-01  1.857e-01  8.002e-02]
#            nit: 0
#           cost: 5.71117304275099e-17
#     optimality: 1.9317880628477724e-13
#    active_mask: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#  unbounded_sol: (array([-4.097e-01,  1.921e-01,  1.857e-01,  8.002e-02]), array([ 1.142e-16]), 4, array([ 1.003e+02,  1.269e+00,  5.345e-03,  5.147e-06]))

# %%
1-b.x[1]/huuregB
# Out:
# -2.053535563817377e-09

# %%
hcomp =  orbit_average(completion_ecc(geoEcc), geoEcc)
zval = 0.5*(b.x[0] + hcomp)*Tr_ecc_geo_ratio(geoEcc)
zval
# Out:
# -0.11878109293429207

# %%
# zvalComp = -0.0892184417213
# zval - zvalComp

# %%
from scipy.optimize import lsq_linear
def lbasis(lmax):
    return [1., ((lmax + 1)), ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3)), ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3)/(2*lmax - 1)/(2*lmax + 5))]

def lfit(huul, lminTest, lmaxTest):
    ysum = np.array([np.sum(huul[:lmax + 1, 1]) for lmax in range(lminTest, lmaxTest + 1)])
    xsum = np.array([lbasis(lmax) for lmax in range(lminTest, lmaxTest + 1)])
    b = lsq_linear(xsum, ysum)
    return b.x[0], b.x[1]

def redshift_fit_plot(gauge, geoEcc huuData = None):
    if huuData is None:
        fn = "ecc_script/redshift_a{}_p{}_e{}_"+gauge+".npy")
        huuData = np.load(fn)
    huul = orbit_average_ecc(huuData, geoEcc, axis = 2)
    huuregB = orbit_average_ecc(huu_reg_ecc(geoEcc), geoEcc)
    datareg = huul - huuregB
    lmax = huul.shape[0] - 1
    ymin = np.min(np.abs(datareg[1:lmax + 1]))/5
    ymax = 5*np.max(np.abs(datareg[1:lmax +1]))
    plt.loglog(lmodes, np.abs(datareg[1:lmax + 1]))
    for i in range(20):
        plt.loglog(lmodes, ymax*10.**(2-0.5*i)*lmodes**(-2), '--', color='gray')
    plt.ylim(ymin, ymax)
    plt.xlim(1, lmax)
    plt.xlabel("$l$")
    plt.ylabel("$|h_{uu}^l - B_0|$")
    plt.show()

def redshift_fit_recon(gauge, geoEcc):
    fn = "ecc_script/redshift_a{}_p{}_e{}_"+gauge+".npy")
    huuData = np.load(fn)
    huul = orbit_average_ecc(huuData, geoEcc, axis = 2)
    huuregB = orbit_average_ecc(huu_reg_ecc(geoEcc), geoEcc)
    huuTest = []
    huuRegTest = []
    for lmin in range(10, 15):
        for lmax in range(25, 30):
            b = lfit(huul, lmin, lmax)
            huuTest.append(b[0])
            huuRegTest.append(b[1])

    huus = np.sort(np.array(huuTest))[2:-2]
    return np.mean(huus), np.sqrt(np.cov(huus)), np.mean(huuRegTest) - huuregB

def redshift_fit(gauge, geoEcc):
    huuData = redshift_fit_recon(gauge, geoEcc)
    hcomp =  orbit_average_ecc(completion_ecc(geoEcc), geoEcc)
    zval = 0.5*(huuData[0] + hcomp)*Tr_ecc_geo_ratio(geoEcc)
    zerr = 0.5*(huuData[1])*Tr_ecc_geo_ratio(geoEcc)
    return zval, zerr, huuData[2]

# %% [markdown]
# ## Inclined Test

# %%
geoInc = KerrGeodesic(0.5, 9., 0., 0.9, 2**7)
lmax = 30
huuDataIRG = redshift_calc_inc('IRG', lmax, geoInc, krange = [-20, 20])
huuDataORG = redshift_calc_inc('ORG', lmax, geoInc, krange = [-20, 20])
huuDataSAAB = redshift_calc_inc('SAAB', lmax, geoInc, krange = [-20, 20])
# Out:
#  13%|█▎        | 4/31 [26:00<2:53:01, 384.51s/it]/Users/znasipak/opt/anaconda3/envs/pybhpt-env/lib/python3.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in reciprocal
# 100%|██████████| 31/31 [1:44:24<00:00, 202.09s/it]
# 100%|██████████| 31/31 [1:43:11<00:00, 199.72s/it]
# 100%|██████████| 31/31 [2:52:07<00:00, 333.14s/it]

# %%
geoInc = KerrGeodesic(0.5, 9., 0., 0.9, 2**7)
huuDataSAAB2 = redshift_calc_inc('SAAB', lmax, geoInc, krange = [-20, 20])
# Out:
#  19%|█▉        | 6/31 [53:31<3:36:01, 518.46s/it]/Users/znasipak/opt/anaconda3/envs/pybhpt-env/lib/python3.7/site-packages/ipykernel_launcher.py:46: RuntimeWarning: invalid value encountered in reciprocal
# 100%|██████████| 31/31 [2:30:01<00:00, 290.37s/it]

# %%
huuDataIRGKPlus = redshift_calc_inc('IRG', lmax, geoInc, krange = [16, 20])
huuDataIRGKMinus = redshift_calc_inc('IRG', lmax, geoInc, krange = [-20, -16])

# %%
huuDataIRGKPlus2 = redshift_calc_inc('IRG', lmax, geoInc, krange = [21, 25])
huuDataIRGKMinus2 = redshift_calc_inc('IRG', lmax, geoInc, krange = [-25, -21])

# %%
huuDataIRGAdd = (huuDataIRG[0] + huuDataIRGKPlus[0] + huuDataIRGKMinus[0], huuDataIRG[1] + huuDataIRGKPlus[1] + huuDataIRGKMinus[1])

# %%
# plt.plot(np.abs(np.mean(huuData[0][1:], axis=2)))
lmaxTemp = huuDataIRG[0].shape[0] - 2
# lmaxTemp = lmax
lmodes = np.arange(1., lmaxTemp+1)
huuregB = orbit_average_inc(huu_reg_inc(geoInc), geoInc)
huul = orbit_average_inc(huuDataORG[0][:lmaxTemp+1], geoInc, axis = 1)
huul2 = orbit_average_inc(huuDataIRG[0][:lmaxTemp+1], geoInc, axis = 1)
huul3 = 4.*orbit_average_inc(huuDataSAAB2[0][:lmaxTemp+1], geoInc, axis = 1)
data = huul
datareg1 = huul - huuregB
datareg2 = huul2 - huuregB
datareg3 = huul3 - huuregB
ymin = np.min(np.abs(datareg[1:]))/5
ymax = 5*np.max(np.abs(datareg[1:]))
plt.figure(figsize=(10,10))
plt.loglog(lmodes, np.abs(data[1:, 1]), 'o', label = '$h_{uu}^l$', mfc='none', ms=10)
plt.loglog(lmodes, np.abs(datareg1[1:, 1]), 'v', label = '$h_{uu}^{l,\mathrm{ORG}} - \Phi^S_{[0]}$', mfc='none', ms=10)
plt.loglog(lmodes, np.abs(datareg2[1:, 1]), 's', label = '$h_{uu}^{l,\mathrm{IRG}} - \Phi^S_{[0]}$', mfc='none', ms=10)
plt.loglog(lmodes, np.abs(datareg3[1:, 1]), 'D', label = '$h_{uu}^{l,\mathrm{sAAB}} - \Phi^S_{[0]}$', mfc='none', ms=10)
# plt.loglog(lmodes, np.abs(datareg[1:, 1]), '.')
for i in range(20):
    plt.loglog(lmodes, ymax*10.**(2-0.5*i)*lmodes**(-2), '--', color='gray')
plt.ylim(ymin, ymax)
plt.xlim(1, lmaxTemp)
plt.xlabel("$l$")
plt.ylabel("$|h_{uu}^{R,l}|$")
plt.gca().set_xticks([1, 2, 5, 10, 20])
plt.gca().get_xaxis().set_major_formatter(mpl.ticker.ScalarFormatter())
# plt.legend()
plt.show()

# %%
from scipy.optimize import lsq_linear
def lbasis(lmax):
    return [1., ((lmax + 1)), ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3)), ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3)/(2*lmax - 1)/(2*lmax + 5))]

def lfit(huul, lminTest, lmaxTest):
    ysum = np.array([np.sum(huul[:lmax + 1, 1]) for lmax in range(lminTest, lmaxTest + 1)])
    xsum = np.array([lbasis(lmax) for lmax in range(lminTest, lmaxTest + 1)])
    b = lsq_linear(xsum, ysum)
    return b.x[0], b.x[1]

def redshift_fit_recon_inc(huul, geo, lmins = [10, 15], lmaxs = [25, 30]):
    huuregB = orbit_average_inc(huu_reg_inc(geo), geo)
    huuTest = []
    huuRegTest = []
    for lmin in range(lmins[0], lmins[1]):
        for lmax in range(lmaxs[0], lmaxs[1]):
            b = lfit(huul, lmin, lmax)
            huuTest.append(b[0])
            huuRegTest.append(b[1])

    huus = np.sort(np.array(huuTest))
    return np.mean(huus), np.sqrt(np.cov(huus)), np.mean(huuRegTest) - huuregB

def redshift_fit_inc(huul, geo, lmins = [10, 15], lmaxs = [25, 30]):
    huuData = redshift_fit_recon_inc(huul, geo, lmins = lmins, lmaxs = lmaxs)
    hcomp =  orbit_average_inc(completion_inc(geo), geo)
    zval = 0.5*(huuData[0] + hcomp)*Tth_inc_geo_ratio(geo)
    zerr = 0.5*(huuData[1])*Tth_inc_geo_ratio(geo)
    return zval, 3.*zerr, huuData[2]

# %%
print(redshift_fit_inc(huul, geoInc))
print(redshift_fit_inc(huul2, geoInc))
print(redshift_fit_inc(huul3, geoInc))
# Out:
# (-0.2611779362370012, 8.810750195907083e-06, 1.2016083017485357e-08)
# (-0.2611779245307437, 8.810797516890694e-06, 1.2016934974878879e-08)
# (-0.2611778920024803, 8.788286275194018e-06, 1.0508457104485558e-08)
# /Users/znasipak/opt/anaconda3/envs/pybhpt-env/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in reciprocal

# %%
(1, 2) in [(1, 2), (3, 2)]
# Out:
# True

# %%
from scipy.optimize import lsq_linear
def lbasis(lmax):
    return [1., ((lmax + 1)), ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3)), ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3)/(2*lmax - 1)/(2*lmax + 5))]

# def lbasis(lmax):
#     return [1., ((lmax + 1)), ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3))]

# def lbasis(lmax):
#     return [1., ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3)), ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3)/(2*lmax - 1)/(2*lmax + 5))]

lminTest = 5
lmaxTest = lmax
ysum = np.array([np.sum(huul[:lmax + 1, 1]) for lmax in range(lminTest, lmaxTest + 1)])
xsum = np.array([lbasis(lmax) for lmax in range(lminTest, lmaxTest + 1)])

b = lsq_linear(xsum, ysum)
print(b)
# Out:
#  active_mask: array([0., 0., 0., 0.])
#         cost: 5.71325344838128e-09
#          fun: array([-4.05916267e-06,  3.22710938e-07,  4.83264502e-06,  6.50609695e-06,
#         6.71239638e-06,  5.84186181e-06,  3.14294890e-06, -1.17629940e-07,
#        -4.12969989e-06, -9.15688151e-06, -1.43401996e-05, -2.01092034e-05,
#        -2.64205555e-05, -3.27557733e-05, -3.93965609e-05,  3.73125940e-05,
#         4.29190392e-05,  3.58457032e-05,  2.85451602e-05,  2.09375492e-05,
#         1.30224656e-05,  5.12430101e-06, -2.86150392e-06, -1.10642698e-05,
#        -1.92025143e-05, -2.74515176e-05])
#      message: 'The unconstrained solution is optimal.'
#          nit: 0
#   optimality: 1.6044943151882762e-12
#       status: 3
#      success: True
#            x: array([-0.41392927,  0.19378405,  0.18456836, -0.02270416])

# %%
b.x[1] - huuregB
# Out:
# -9.341994621409055e-06

# %%
lmax = huuDataIRG[0].shape[0] - 1
lmodes = np.arange(1., lmax+1)
huuregB = b.x[1]
huul = orbit_average_polar(huuDataIRG[0], geoInc, axis = 1)
datareg = huul - huuregB
ymin = np.min(np.abs(datareg[1:]))/5
ymax = 5*np.max(np.abs(datareg[1:]))
plt.loglog(lmodes, np.abs(datareg[1:]))
for i in range(20):
    plt.loglog(lmodes, ymax*10.**(2-0.5*i)*lmodes**(-2), '--', color='gray')
plt.ylim(ymin, ymax)
plt.xlim(1, lmax)
plt.xlabel("$l$")
plt.ylabel("$|h_{uu}^l - B_0|$")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/p7/sdzfl46n4bn5p6hwntl5lsqhddqc5w/T/ipykernel_96364/627792576.py in <module>
#       2 lmodes = np.arange(1., lmax+1)
#       3 huuregB = b.x[1]
# ----> 4 huul = orbit_average_polar(huuDataIRG[0], geoInc, axis = 1)
#       5 datareg = huul - huuregB
#       6 ymin = np.min(np.abs(datareg[1:]))/5
#
# NameError: name 'orbit_average_polar' is not defined

# %%
# from pybhpt.geo import KerrGeodesic
# from pybhpt.redshift import circular_redshift_export
# geoCirc = KerrGeodesic(0., 10., 0.0, 1.0, 2**2)
# circular_redshift_export("test.txt", "ORG", 2, geoCirc)

# %%
geo = KerrGeodesic(0., 6., 0., 1.0, 2**2)
m = 2
teuk = TeukolskyMode(-2, m, m, 0, 0, geo)
teuk.solve(geo)
print(teuk.amplitude('Up'),
      teuk.amplitude('Up')/geo.mode_frequency(m, 0, 0)**2, 
      geo.mode_frequency(m, 0, 0)**2)
# Out:
# (0.008763336582675862-0.002949020148629884j) (0.47322017546449613-0.1592470880260136j) 0.018518518518518535

# %%
geo = KerrGeodesic(0.25, 6., 0., 1.0, 2**2)
m = 2
teuk = TeukolskyMode(-2, m, m, 0, 0, geo)
teuk.solve(geo)
print(teuk.amplitude('Up'),
      teuk.amplitude('Up')/geo.mode_frequency(m, 0, 0)**2, 
      geo.mode_frequency(m, 0, 0)**2)
# Out:
# (0.007982096601320758-0.0027202774414030856j) (0.44582198454384575-0.15193495493846934j) 0.017904223833842214

# %%
geo = KerrGeodesic(0., 7., 0., 1.0, 2**2)
m = 2
lmodes = np.arange(m, 16)
jmodes = np.arange(m, 40)
Zs = np.zeros(lmodes.shape[0], dtype=np.complex128)
for j in jmodes:
    teuk = TeukolskyMode(-2, j, m, 0, 0, geo)
    teuk.solve(geo)
    for l in lmodes:
        Z = teuk.couplingcoefficient(l)*teuk.amplitude('Up')
        Zs[l-m] += Z

# %%
comparison=np.array([7.96233358e-01-2.64339239e-01j, 3.26116438e-02-1.78284989e-02j,
       3.01992796e-03-1.94391386e-03j, 1.08462121e-04-7.90232072e-05j,
       7.07885016e-06-5.62397831e-06j, 2.01742927e-07-1.72430029e-07j,
       1.01260565e-08-9.18856175e-09j, 2.35628290e-10-2.25437583e-10j,
       9.59773545e-12-9.61726001e-12j, 1.87893538e-13-1.96359571e-13j,
       6.43702345e-15-6.98757969e-15j, 1.08572641e-16-1.22077267e-16j,
       3.20890107e-18-3.72706056e-18j, 4.75046181e-20-5.68798318e-20j])

# %%
amps=2.*Zs/geo.mode_frequency(m, 0, 0)**2
amps
# Out:
# array([7.96233350e-01-2.64339220e-01j, 3.26116422e-02-1.78284971e-02j,
#        3.01992799e-03-1.94391369e-03j, 1.08462123e-04-7.90232012e-05j,
#        7.07885019e-06-5.62397786e-06j, 2.01742910e-07-1.72430002e-07j,
#        1.01260550e-08-9.18855955e-09j, 2.35628258e-10-2.25437525e-10j,
#        9.59773216e-12-9.61725596e-12j, 1.87893436e-13-1.96359453e-13j,
#        6.43701920e-15-6.98757466e-15j, 1.08572549e-16-1.22077157e-16j,
#        3.20889780e-18-3.72705656e-18j, 4.75045635e-20-5.68797632e-20j])

# %% [markdown]
# ## Generic

# %%
class ModeSummer:
    def __init__(self, shape, dtype=np.float64, error_compare = None, rtol = 1.e-14, atol = 1.e-12):
        self.sum = np.zeros(shape, dtype=dtype)
        self.prior = np.zeros(shape, dtype=dtype) + 1.e-20
        self.max_value = np.abs(self.sum)
        self.rel_error = np.ones(shape)
        self.abs_error = np.ones(shape)
        self.error_compare = error_compare
        self.rtol = rtol
        self.atol = atol
        self.passes = 0
        self.precision_loss = np.ones(shape)
        self.eps = np.abs(np.finfo(dtype).eps)
    
    def add(self, term):
        self.prior = self.sum.copy()
        self.prior[np.abs(self.prior) == 0.] = 1.e-20
        self.sum += term
        self.track_precision(term)

        if self.error_compare is None:
            sum_compare = self.prior
        else:
            sum_compare = self.error_compare
        
        self.rel_error = np.abs(1. - self.sum/sum_compare)
        self.abs_error = np.abs(self.sum - self.prior)

    def track_precision(self, term):
        absTerm = np.abs(term)
        self.max_value = np.maximum(self.max_value, absTerm)
        absSum = np.abs(self.sum)
        nonzeros = (absSum > 0)
        zeros = np.invert(nonzeros)
        loss_check = absTerm.copy()
        loss_check[nonzeros] = (np.abs(self.prior[nonzeros]) + absTerm[nonzeros])/absSum[nonzeros]
        loss_check[zeros] = np.log10(absTerm[zeros])
        prec_loss = (loss_check >= 1.)
        prec_gain = np.invert(prec_loss)
        nonzero_gain = np.minimum(prec_gain, nonzeros)
        

        self.precision_loss[prec_loss] *= loss_check[prec_loss]
        self.precision_loss[nonzero_gain] *= np.abs(self.prior[nonzero_gain]/absTerm[nonzero_gain])
        self.precision_loss[self.precision_loss < 1.] = 1.
        self.precision_loss

    def error_test(self):
        rel_error_check = self.rel_error < (self.rtol*self.precision_loss)
        abs_error_check = self.abs_error < self.atol
        tot_error_check = np.maximum(rel_error_check, abs_error_check)
        
        if np.all(tot_error_check):
            self.passes += 1

    @property
    def precisions(self):
        return self.precision_loss*self.eps

# %%
def construct_hertz_radial_components(hertz, samples = 2**6):
    samples_half = int(samples/2 + 1)
    hertzR0In = np.array([hertz.radialsolution('In', i) for i in range(samples_half)])
    hertzR0Up = np.array([hertz.radialsolution('Up', i) for i in range(samples_half)])
    hertzR1In = np.array([hertz.radialderivative('In', i) for i in range(samples_half)])
    hertzR1Up = np.array([hertz.radialderivative('Up', i) for i in range(samples_half)])
    hertzR2In = np.array([hertz.radialderivative2('In', i) for i in range(samples_half)])
    hertzR2Up = np.array([hertz.radialderivative2('Up', i) for i in range(samples_half)])
    hertzR = np.array(
        [[np.concatenate((hertzR0In, np.flip(hertzR0In)[1:-1])), np.concatenate((hertzR0Up, np.flip(hertzR0Up)[1:-1]))], 
        [np.concatenate((hertzR1In, np.flip(hertzR1In)[1:-1])), np.concatenate((hertzR1Up, np.flip(hertzR1Up)[1:-1]))], 
        [np.concatenate((hertzR2In, np.flip(hertzR2In)[1:-1])), np.concatenate((hertzR2Up, np.flip(hertzR2Up)[1:-1]))]])
    return hertzR

def construct_hertz_polar_spin_weighting(hertz, samples = 2**6):
    samples_half = int(samples/2 + 1)
    th = np.array([hertz.polarpoint(i) for i in range(samples_half)])
    thp = full_libration(th)
    sth = np.sin(thp)
    spinWeightingPolar = np.array(
        [pow(sth, -2),
        pow(sth, -1),
        pow(sth, 0)]
    )
    return spinWeightingPolar

def redshift_mode_inc(coeffs, hertz, l, samples = 2**6):
    m = hertz.azimuthalmode
    omega = hertz.frequency
    s_sgn = np.sign(hertz.spinweight)
    huu = np.zeros((samples, 2), dtype=np.complex128)
    hertzR = construct_hertz_radial_components_circ(hertz)
    spinWeightingPolar = construct_hertz_polar_spin_weighting(hertz, samples=samples)
    for ns in range(0, 3):
        scalar_coupling = 0.
        llmin = np.max([np.abs(m), 2, l - 3 + ns])
        llmax = np.max([llmin, l + 3 - ns])
        for ll in range(llmin, llmax + 1):
            Jterm = spin_operator_normalization(s_sgn*2, ns, ll)
            scalar_coupling += Jterm*hertz.couplingcoefficient(ll)*Asjlm(s_sgn*(2-ns), l, ll, m)
        for nt in range(0, 3):
            for nph in range(0, 3):
                pref = (1.j*m)**nph*(-1.j*omega)**nt
                for nr in range(0, 3):
                    if nt + nr + ns + nph <= 2:
                        hNabcd0 = np.array([coeffs(0, nt, nr, ns, nph, 0, i) for i in range(samples)])
                        hNabcd0 *= spinWeightingPolar[ns]
                        hNabcd = np.array([hNabcd0, hNabcd0]).T
                        huuTerm = -pref*hNabcd*scalar_coupling*hertzR[nr]
                        # if np.sum(huuTerm) == 0 and np.sum(hNabcd0) != 0:
                        #     print(nt, nr, ns, nph)
                        #     print(pref, spinWeightingPolar[ns], scalar_coupling, hertzR[nr])
                        huu += huuTerm
    return huu

def redshift_calc_inc(gauge, lmax, geo, krange = [-10, 10]):
    if isinstance(gauge, str):
        if gauge == "SAAB":
            return redshift_calc_inc(["SAAB0", "SAAB4"], lmax, geo, krange=krange)
        elif gauge == "ASAAB":
            return redshift_calc_inc(["ASAAB0", "ASAAB4"], lmax, geo, krange=krange)
        gauges = [gauge]
    else:
        gauges = gauge
    coeffs = []
    for gauge in gauges:
        coeffs.append(RedshiftCoefficients(gauge, geo))
    samples = 2*(geo.polarpoints.shape[0] - 1)
    huuYlm = np.zeros((lmax + 1, lmax + 1, samples, 2), dtype=np.complex128)
    Ylms = np.zeros((lmax + 1, lmax + 1, samples, 2))
    th = geo.polarpoints
    thp = full_libration(th)
    for m in range(-lmax, lmax + 1):
        for l in range(m, lmax + 1):
            ylm0 = np.array([np.real(sph_harm(m, l, 0., th)) for th in thp])
            ylm = np.array([ylm0, ylm0]).T
            Ylms[l, m] = ylm
    s = choose_spin_from_gauge(gauges[0])
    for m in tqdm(range(0, lmax + 1)):
        jmin = np.max([abs(s), abs(m)])
        jmax = lmax + 19
        for j in range(jmin, jmax + 1):
            kmin = krange[0]
            kmax = krange[1]
            for k in range(kmin, kmax + 1):
                teuk = TeukolskyMode(s, j, m, k, 0, geo)
                teuk.solve(geo)
                psis = []
                for i, gauge in enumerate(gauges):
                    psis.append(HertzMode(teuk, gauge))
                    psis[i].solve()
                phaseUp = m*geo.azimuthalpolar - teuk.frequency*geo.timepolar
                phaseDown = np.flip(-phaseUp)[1:-1]
                phase = np.concatenate((phaseUp, phaseDown)) - 2.*np.pi*k*np.arange(samples)/samples
                phaseArray = np.array([phase, phase]).T
                for l in range(abs(m), lmax + 1):
                    for coeff, psi in zip(coeffs, psis):
                        huuMode = redshift_mode_inc(coeff, psi, l, samples=samples)
                        if np.isnan(np.sum(huuMode)):
                            print("Error ", j, l, m, k)
                        else:
                            huuTemp = huuMode*np.exp(1.j*phaseArray)*Ylms[l, m]
                            huuYlm[l, m] += huuTemp
    
    huuYl = np.zeros((lmax + 1, samples, 2))
    for l in range(0, lmax + 1):
        huuYl[l] += 2.*np.real(huuYlm[l, 0])
        for m in range(1, l + 1):
            huuYl[l] += 2.*np.real(huuYlm[l, m])
            huuYl[l] += 2.*np.real(np.roll(huuYlm[l, m], int(samples/2)))

    return huuYl, huuYlm

def redshift_mode_gen(coeffs, hertz, hertzR, hertzTh, l, samples = 2**6):
    m = hertz.azimuthalmode
    omega = hertz.frequency
    s_sgn = np.sign(hertz.spinweight)
    huu = np.zeros((2, samples, samples), dtype=np.complex128)
    # hertzR = construct_hertz_radial_components(hertz, samples=samples)
    # hertzTh = construct_hertz_polar_spin_weighting(hertz, samples=samples)
    for ns in range(0, 3):
        scalar_coupling = 0.
        llmin = np.max([np.abs(m), 2, l - 3 + ns])
        llmax = np.max([llmin, l + 3 - ns])
        for ll in range(llmin, llmax + 1):
            Jterm = spin_operator_normalization(s_sgn*2, ns, ll)
            scalar_coupling += Jterm*hertz.couplingcoefficient(ll)*Asjlm(s_sgn*(2-ns), l, ll, m)
        for nt in range(0, 3):
            for nph in range(0, 3):
                pref = (1.j*m)**nph*(-1.j*omega)**nt
                for nr in range(0, 3):
                    if nt + nr + ns + nph <= 2:
                        hNabcd0 = np.array([[coeffs(0, nt, nr, ns, nph, i, j) for j in range(samples)] for i in range(samples)])
                        huuR = -pref*hertzR[nr]
                        huuTh = scalar_coupling*hertzTh[ns]
                        huuTerm = np.array([np.outer(radial, huuTh)*hNabcd0 for radial in huuR])
                        # if np.sum(huuTerm) == 0 and np.sum(hNabcd0) != 0:
                        #     print(nt, nr, ns, nph)
                        #     print(pref, spinWeightingPolar[ns], scalar_coupling, hertzR[nr])
                        huu += huuTerm
    return huu

# import numba as nb
# from numba import jit

# @jit(parallel=True)
def redshift_calc_gen(gauge, lmax, geo, mrange = None, krange = [-10, 10], nrange = [-10, 10]):
    if mrange is None:
        mrange = np.array([0, lmax])
    mmin = mrange[0]
    mmax = mrange[1]

    if isinstance(gauge, str):
        if gauge == "SAAB":
            return redshift_calc_gen(["SAAB0", "SAAB4"], lmax, geo, krange=krange, nrange=nrange)
        elif gauge == "ASAAB":
            return redshift_calc_gen(["ASAAB0", "ASAAB4"], lmax, geo, krange=krange, nrange=nrange)
        gauges = [gauge]
    else:
        gauges = gauge
    coeffs = []
    for gauge in gauges:
        coeffs.append(RedshiftCoefficients(gauge, geo))
    samples = 2*(geo.polarpoints.shape[0] - 1)
    huuYlm = np.zeros((lmax + 1, lmax + 1, 2, samples, samples), dtype=np.complex128)
    huuTemp = np.zeros((samples, samples), dtype=np.complex128)
    Ylms = np.zeros((lmax + 1, lmax + 1, samples, samples))
    th = geo.polarpoints
    thp = full_libration(th)
    r = geo.radialpoints
    rp = full_libration(r)

    kmin = krange[0]
    kmax = krange[1]
    nmin = nrange[0]
    nmax = nrange[1]
    for m in range(mmin, mmax + 1):
        for l in range(m, lmax + 1):
            ylm0 = np.array([np.real(sph_harm(m, l, 0., th)) for th in thp])
            ylm = np.array([ylm0 for r in rp])
            # ylm = np.array([ylm0M, ylm0M])
            Ylms[l, m] = ylm
    s = choose_spin_from_gauge(gauges[0])
    for m in tqdm(range(mmin, mmax + 1)):
        jmin = np.max([abs(s), abs(m)])
        jmax = lmax + 19
        for j in range(jmin, jmax + 1):
            for k in range(kmin, kmax + 1):
                for n in range(nmin, nmax + 1):
                    teuk = TeukolskyMode(s, j, m, k, n, geo)
                    teuk.solve(geo)
                    psis = []
                    for i, gauge in enumerate(gauges):
                        psis.append(HertzMode(teuk, gauge))
                        psis[i].solve()
                    phaseUpTh = m*geo.azimuthalpolar - teuk.frequency*geo.timepolar
                    phaseDownTh = np.flip(-phaseUpTh)[1:-1]
                    phaseTh = np.concatenate((phaseUpTh, phaseDownTh)) - 2.*np.pi*k*np.arange(samples)/samples
                    phaseUpR = m*geo.azimuthalradial - teuk.frequency*geo.timeradial
                    phaseDownR = np.flip(-phaseUpR)[1:-1]
                    phaseR = np.concatenate((phaseUpR, phaseDownR)) - 2.*np.pi*n*np.arange(samples)/samples
                    phase = np.add.outer(phaseR, phaseTh)
                    for coeff, psi in zip(coeffs, psis):
                        psiR = construct_hertz_radial_components(psi, samples=samples)
                        psiTh = construct_hertz_polar_spin_weighting(psi, samples=samples)
                        for l in range(abs(m), lmax + 1):
                            huuMode = redshift_mode_gen(coeff, psi, psiR, psiTh, l, samples=samples)
                            if np.isnan(np.sum(huuMode)):
                                print("Error ", j, l, m, k, n)
                            else:
                                for i in range(2): 
                                    huuTemp = huuMode[i]*np.exp(1.j*phase)*Ylms[l, m]
                                    huuYlm[l, m][i] += huuTemp
    
    huuYl = np.zeros((lmax + 1, 2, samples, samples))
    for l in range(0, lmax + 1):
        huuYl[l] += 2.*np.real(huuYlm[l, 0])
        for m in range(1, l + 1):
            huuYl[l] += 2.*np.real(huuYlm[l, m])
            huuYl[l] += 2.*np.real(np.roll(huuYlm[l, m], int(samples/2), axis = 1))

    return huuYl, huuYlm

def orbit_average(func, geo, axis = 0):
    th = geo.polarpoints
    r = geo.radialpoints
    thp = full_libration(th)
    rp = full_libration(r)
    q = geo.blackholespin
    sig = np.add.outer(rp**2, q**2*np.cos(thp)**2)
    if func.shape[1] != 2:
        sigA = np.array(sig)
    else:
        sigA = np.array([sig, sig])
    return np.mean(np.mean(func*sigA, axis = axis), axis = axis)/np.mean(sig)

# %%
geoTestReg = KerrGeodesic(0.5, 10., 0.1, 0.9, 2**8)
test=orbit_average(huu_reg(geoTestReg), geoTestReg)
print(test)
# Out:
# 0.19201547823137552
# /Users/znasipak/opt/anaconda3/envs/pybhpt-env/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in reciprocal

# %%
def huu_reg(geo):
    En = geo.orbitalenergy
    Lz = geo.orbitalangularmomentum
    Qc = geo.carterconstant
    r = geo.radialpoints
    r0 = full_libration(r)
    th = geo.polarpoints
    th0 = full_libration(th)
    q = geo.blackholespin
    rp = np.array([r0 for th in th0]).T
    thp = np.array([th0 for r in r0])
    return huu_reg_gen(q, En, Lz, Qc, rp, thp)

# %%
# geoTest = KerrGeodesic(0.5, 10., 0., 0.9, 2**6)
# huuGenTest2 = redshift_calc_inc("IRG", 4, geoTest, krange=[-8,8])

# %%
geoTest = KerrGeodesic(0.5, 10., 0.1, 0.9, 2**6)
# # huuGenTest = redshift_calc_gen("IRG", 10, geoTest, krange=[-8,8], nrange=[-10,10])
# huuGenTest3 = redshift_calc_gen("IRG", 20, geoTest, krange=[-12,12], nrange=[-15,15])

# %%
# geoTest = KerrGeodesic(0.5, 10., 0.1, 0.9, 2**6)
# huuGenTest2 = redshift_calc_gen("IRG", 20, geoTest, mrange=[0, 0], krange=[-12,12], nrange=[-15,15])

# %%
huuM0=np.load("genAttempt/huu_m0.npy")
for m in range(1, 20):
    huuM0 += np.load("genAttempt/huu_m"+str(m)+".npy")

# %%
huuYl = np.zeros(huuM0.shape[1:])
samples = huuM0.shape[-1]
for l in range(0, huuYl.shape[0]):
    huuYl[l] += 2.*np.real(huuM0[l, 0])
    for m in range(1, l + 1):
        huuYl[l] += 2.*np.real(huuM0[l, m])
        huuYl[l] += 2.*np.real(np.roll(huuM0[l, m], int(samples/2), axis = 1))

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
mpl.rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
mpl.rc('text', usetex=True)
mpl.rc('font', **{'size' : 30})

# %%
huuDataTest = huuYl
lmax = huuDataTest.shape[0] - 2
lmodes = np.arange(1., lmax+1)
huuregB = orbit_average(huu_reg(geoTest), geoTest)
huul = orbit_average(huuDataTest, geoTest, axis = 2)
huuregB = 0.19381726
datareg = huul - huuregB
ymin = np.min(np.abs(datareg[1:lmax + 1]))/5
ymax = 5*np.max(np.abs(datareg[1:lmax +1]))
plt.figure(figsize=(10,10))
plt.loglog(lmodes, np.abs(huul[1:lmax + 1]), 'o', mfc='none', markersize=10)
plt.loglog(lmodes, np.abs(datareg[1:lmax + 1]), 'v', mfc='none', markersize=10)
# plt.loglog(lmodes, np.abs(huul[1:lmax + 1]))
# plt.loglog(lmodes, np.abs(datareg[1:lmax + 1]))
for i in range(20):
    plt.loglog(lmodes, ymax*10.**(2-0.5*i)*lmodes**(-2), '--', color='gray')
plt.ylim(ymin, ymax)
plt.xlim(1, lmax)
plt.xlabel("$l$")
plt.ylabel("$|h_{uu}^l|$")
plt.gca().set_xticks([1, 2, 5, 10])
plt.gca().get_xaxis().set_major_formatter(mpl.ticker.ScalarFormatter())
plt.show()
# Out:
# /Users/znasipak/opt/anaconda3/envs/pybhpt-env/lib/python3.7/site-packages/ipykernel_launcher.py:24: RuntimeWarning: invalid value encountered in reciprocal

# %%
from scipy.optimize import lsq_linear
def lbasis(lmax):
    return [1., ((lmax + 1)), ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3)), ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3)/(2*lmax - 1)/(2*lmax + 5))]

# def lbasis(lmax):
#     return [1., ((lmax + 1)), ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3))]

# def lbasis(lmax):
#     return [1., ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3)), ((lmax + 1)/(2*lmax + 1)/(2*lmax + 3)/(2*lmax - 1)/(2*lmax + 5))]

lminTest = 5
lmaxTest = lmax - 1
ysum = np.array([np.sum(huul[:lmax + 1, 1]) for lmax in range(lminTest, lmaxTest + 1)])
xsum = np.array([lbasis(lmax) for lmax in range(lminTest, lmaxTest + 1)])

b = lsq_linear(xsum, ysum)
print(b)
# Out:
#  active_mask: array([0., 0., 0., 0.])
#         cost: 1.9708384596959288e-10
#          fun: array([-2.58374281e-06,  1.00577361e-05, -1.14005022e-05,  3.72559950e-06,
#         2.50081653e-06, -7.40975515e-06,  4.90147655e-06,  1.87839880e-07,
#        -3.12431994e-06,  5.23704095e-06, -1.15754372e-06, -1.28382126e-06,
#         3.09237946e-06, -2.74320390e-06])
#      message: 'The unconstrained solution is optimal.'
#          nit: 0
#   optimality: 2.453592884421596e-14
#       status: 3
#      success: True
#            x: array([-0.41565756,  0.19381726,  0.20751199, -0.47545461])

# %% [markdown]
# # Hertz Tests

# %%
from pybhpt.geo import KerrGeodesic
from pybhpt.radial import RadialTeukolsky
from pybhpt.teuk import TeukolskyMode
from pybhpt.hertz import HertzMode
import numpy as np
import matplotlib.pyplot as plt

# %%
gauge = 'IRG'
geo = KerrGeodesic(0.0, 10., 0., 1.0, 2**2)
teuk = TeukolskyMode(-2, 2, 2, 0, 0, geo)
teuk.solve(geo)
teuk2 = TeukolskyMode(2, 2, 2, 0, 0, geo)
teuk2.solve(geo)
# print(teuk.teukolsky_amplitude('Up'), teuk.teukolsky_amplitude('In'))
# print(teuk2.teukolsky_amplitude('Up'), teuk2.teukolsky_amplitude('In'))
hertz = HertzMode(teuk, gauge)
hertz.solve()
hertz2 = HertzMode(teuk2, gauge)
hertz2.solve()
print(1.-hertz.amplitude('In')/hertz2.amplitude('In'))
print(1.-hertz.amplitude('Up')/hertz2.amplitude('Up'))
# Out:
# -1.0428790879943498e-15j
# (6.661338147750939e-16+1.0042667994196633e-16j)

# %%
teuk.polarderivative2(0)
# Out:
# 0.3153915652525201

# %%
teuk2.flipspinweight()
print(teuk2.homogeneousradialsolution("Up",0), teuk2.homogeneousradialsolution("In",0))
# Out:
# (7805.205087483132-3566.0391460544997j) (5754.689772338279+1787.9648163203212j)

# %%
print(teuk.homogeneousradialsolution("Up",0), teuk.homogeneousradialsolution("In",0))
print(teuk.homogeneousradialderivative("Up",0), teuk.homogeneousradialderivative("In",0))
print(teuk.homogeneousradialderivative2("Up",0), teuk.homogeneousradialderivative2("In",0))
# Out:
# (7805.205087483132-3566.0391460544997j) (5754.689772338277+1787.9648163203208j)
# (-1154.096840225514-57.03881320255073j) (2478.4935684542634+1028.8022626558165j)
# (180.47798538661954+47.12152909987104j) (759.9558699786119+468.93583025888967j)

# %%
print(teuk.amplitude('Up'), teuk.amplitude('In'))
print(teuk2.amplitude('Up'), teuk2.amplitude('In'))
# Out:
# (0.0011206407919254206-0.0003057608384581538j) (0.0014710247263310524+0.00038613052992468545j)
# (0.0011206407919254215-0.0003057608384581538j) (0.0014710247263310528+0.0003861305299246838j)

# %%
Rt=RadialTeukolsky(-2, 2, 2, 0., teuk2.frequency, np.array([10.]))
Rt.solve('AUTO')

# %%
print(Rt.boundarypoint('Up'), Rt.boundarysolution('Up'), Rt.boundaryderivative('Up'))
print(Rt.radialpoint(0), Rt.radialsolution('Up', 0), Rt.radialderivative('Up', 0))
# Out:
# 632.4555320336758 (-12438348524.679253-10363928701.344622j) (641189319.6786355-799521573.9794998j)
# 10.0 (7805.205087483132-3566.0391460544997j) (-1154.096840225514-57.03881320255073j)

# %% [markdown]
# # Mathematica to Python

# %%
from sympy.parsing.mathematica import parse_mathematica
from sympy import var, Function, N
a, r, l, l1, m1, m, q, Omega = var('a r l l1 m1 m q Omega')
Hertz = Function("HertzFunc")
HertzDagger = Function("HertzDaggerFunc")
mu = Function("muCoupling")
CC = Function("C3Product")

# %% [markdown]
# ## $h_{22}$

# %%
expr="((q^4 - 5*r^4)*(HertzDaggerFunc[l, m, 0] + HertzFunc[l, m, 0])*muCoupling[l, 1]*muCoupling[l, 2])/40"
math_expr=parse_mathematica(expr)
print(math_expr)
# Out:
# (q**4 - 5*r**4)*(HertzDaggerFunc(l, m, 0) + HertzFunc(l, m, 0))*muCoupling(l, 1)*muCoupling(l, 2)/40

# %%
expr="(Sqrt[Pi]*q*(143*Sqrt[30]*m1*Omega*q*((6*I)*r*(q^2 - 7*r^2) - m1*Omega*(q^4 - 21*r^4))*C3Product[l, m, 0, 2, 0, -2, l1, m1, 2]*HertzDaggerFunc[l1, m1, 0] - (286*I)*Sqrt[210]*q^2*(18*r + m1*Omega*(q^2*(I - m1*Omega*r) - 3*r^2*(-3*I + m1*Omega*r)))*C3Product[l, m, 0, 3, 0, -2, l1, m1, 2]*HertzDaggerFunc[l1, m1, 0] + 156*Sqrt[10]*m1*Omega*q^3*(-3*m1*Omega*q^2 + (11*I)*r)*C3Product[l, m, 0, 4, 0, -2, l1, m1, 2]*HertzDaggerFunc[l1, m1, 0] + 52*Sqrt[2310]*m1*Omega*q^4*(1 + I*m1*Omega*r)*C3Product[l, m, 0, 5, 0, -2, l1, m1, 2]*HertzDaggerFunc[l1, m1, 0] - 16*Sqrt[1365]*m1^2*Omega^2*q^5*C3Product[l, m, 0, 6, 0, -2, l1, m1, 2]*HertzDaggerFunc[l1, m1, 0] + 143*Sqrt[30]*m1*Omega*q*((6*I)*r*(q^2 - 7*r^2) - m1*Omega*(q^4 - 21*r^4))*C3Product[l, m, 0, l1, m1, -2, 2, 0, 2]*HertzFunc[l1, m1, 0] + (286*I)*Sqrt[210]*q^2*(18*r + m1*Omega*(q^2*(I - m1*Omega*r) - 3*r^2*(-3*I + m1*Omega*r)))*C3Product[l, m, 0, l1, m1, -2, 3, 0, 2]*HertzFunc[l1, m1, 0] + 156*Sqrt[10]*m1*Omega*q^3*(-3*m1*Omega*q^2 + (11*I)*r)*C3Product[l, m, 0, l1, m1, -2, 4, 0, 2]*HertzFunc[l1, m1, 0] + 52*Sqrt[2310]*m1*Omega*q^4*(-1 - I*m1*Omega*r)*C3Product[l, m, 0, l1, m1, -2, 5, 0, 2]*HertzFunc[l1, m1, 0] - 16*Sqrt[1365]*m1^2*Omega^2*q^5*C3Product[l, m, 0, l1, m1, -2, 6, 0, 2]*HertzFunc[l1, m1, 0] + 429*Sqrt[6]*((-3*I)*m1*Omega*q^4 - 7*q^2*r + 35*r^3*(1 + I*m1*Omega*r))*C3Product[l, m, 0, 1, 0, -1, l1, m1, 1]*HertzDaggerFunc[l1, m1, 0]*muCoupling[l1, 2] + (429*I)*Sqrt[30]*q*(7*r^2*(3 + (2*I)*m1*Omega*r) + q^2*(3 + (6*I)*m1*Omega*r))*C3Product[l, m, 0, 2, 0, -1, l1, m1, 1]*HertzDaggerFunc[l1, m1, 0]*muCoupling[l1, 2] + 572*Sqrt[21]*q^2*((-2*I)*m1*Omega*q^2 - 3*r)*C3Product[l, m, 0, 3, 0, -1, l1, m1, 1]*HertzDaggerFunc[l1, m1, 0]*muCoupling[l1, 2] + 1716*Sqrt[5]*q^3*(I - 2*m1*Omega*r)*C3Product[l, m, 0, 4, 0, -1, l1, m1, 1]*HertzDaggerFunc[l1, m1, 0]*muCoupling[l1, 2] - (104*I)*Sqrt[330]*m1*Omega*q^4*C3Product[l, m, 0, 5, 0, -1, l1, m1, 1]*HertzDaggerFunc[l1, m1, 0]*muCoupling[l1, 2] + 429*Sqrt[6]*(7*r*(q^2 - 5*r^2) + I*m1*Omega*(3*q^4 - 35*r^4))*C3Product[l, m, 0, l1, m1, -1, 1, 0, 1]*HertzFunc[l1, m1, 0]*muCoupling[l1, 2] + (429*I)*Sqrt[30]*q*(7*r^2*(3 + (2*I)*m1*Omega*r) + q^2*(3 + (6*I)*m1*Omega*r))*C3Product[l, m, 0, l1, m1, -1, 2, 0, 1]*HertzFunc[l1, m1, 0]*muCoupling[l1, 2] + 572*Sqrt[21]*q^2*((2*I)*m1*Omega*q^2 + 3*r)*C3Product[l, m, 0, l1, m1, -1, 3, 0, 1]*HertzFunc[l1, m1, 0]*muCoupling[l1, 2] + 1716*Sqrt[5]*q^3*(I - 2*m1*Omega*r)*C3Product[l, m, 0, l1, m1, -1, 4, 0, 1]*HertzFunc[l1, m1, 0]*muCoupling[l1, 2] + (104*I)*Sqrt[330]*m1*Omega*q^4*C3Product[l, m, 0, l1, m1, -1, 5, 0, 1]*HertzFunc[l1, m1, 0]*muCoupling[l1, 2] + (3003*I)*Sqrt[3]*r*(3*q^2 + 5*r^2)*C3Product[l, m, 0, 1, 0, 0, l1, m1, 0]*(-HertzDaggerFunc[l1, m1, 0] + HertzFunc[l1, m1, 0])*muCoupling[l1, 1]*muCoupling[l1, 2] + (2574*I)*Sqrt[7]*q^2*r*C3Product[l, m, 0, 3, 0, 0, l1, m1, 0]*(-HertzDaggerFunc[l1, m1, 0] + HertzFunc[l1, m1, 0])*muCoupling[l1, 1]*muCoupling[l1, 2] + 2574*Sqrt[5]*q^3*C3Product[l, m, 0, 2, 0, 0, l1, m1, 0]*(HertzDaggerFunc[l1, m1, 0] + HertzFunc[l1, m1, 0])*muCoupling[l1, 1]*muCoupling[l1, 2] + 1716*q^3*C3Product[l, m, 0, 4, 0, 0, l1, m1, 0]*(HertzDaggerFunc[l1, m1, 0] + HertzFunc[l1, m1, 0])*muCoupling[l1, 1]*muCoupling[l1, 2]))/90090"
math_expr=parse_mathematica(expr)
print(math_expr)
# Out:
# sqrt(pi)*q*(-16*sqrt(1365)*Omega**2*m1**2*q**5*C3Product(l, m, 0, 6, 0, -2, l1, m1, 2)*HertzDaggerFunc(l1, m1, 0) - 16*sqrt(1365)*Omega**2*m1**2*q**5*C3Product(l, m, 0, l1, m1, -2, 6, 0, 2)*HertzFunc(l1, m1, 0) + 52*sqrt(2310)*Omega*m1*q**4*(-I*Omega*m1*r - 1)*C3Product(l, m, 0, l1, m1, -2, 5, 0, 2)*HertzFunc(l1, m1, 0) + 52*sqrt(2310)*Omega*m1*q**4*(I*Omega*m1*r + 1)*C3Product(l, m, 0, 5, 0, -2, l1, m1, 2)*HertzDaggerFunc(l1, m1, 0) - 104*sqrt(330)*I*Omega*m1*q**4*C3Product(l, m, 0, 5, 0, -1, l1, m1, 1)*HertzDaggerFunc(l1, m1, 0)*muCoupling(l1, 2) + 104*sqrt(330)*I*Omega*m1*q**4*C3Product(l, m, 0, l1, m1, -1, 5, 0, 1)*HertzFunc(l1, m1, 0)*muCoupling(l1, 2) + 156*sqrt(10)*Omega*m1*q**3*(-3*Omega*m1*q**2 + 11*I*r)*C3Product(l, m, 0, 4, 0, -2, l1, m1, 2)*HertzDaggerFunc(l1, m1, 0) + 156*sqrt(10)*Omega*m1*q**3*(-3*Omega*m1*q**2 + 11*I*r)*C3Product(l, m, 0, l1, m1, -2, 4, 0, 2)*HertzFunc(l1, m1, 0) + 143*sqrt(30)*Omega*m1*q*(-Omega*m1*(q**4 - 21*r**4) + 6*I*r*(q**2 - 7*r**2))*C3Product(l, m, 0, 2, 0, -2, l1, m1, 2)*HertzDaggerFunc(l1, m1, 0) + 143*sqrt(30)*Omega*m1*q*(-Omega*m1*(q**4 - 21*r**4) + 6*I*r*(q**2 - 7*r**2))*C3Product(l, m, 0, l1, m1, -2, 2, 0, 2)*HertzFunc(l1, m1, 0) + 1716*sqrt(5)*q**3*(-2*Omega*m1*r + I)*C3Product(l, m, 0, 4, 0, -1, l1, m1, 1)*HertzDaggerFunc(l1, m1, 0)*muCoupling(l1, 2) + 1716*sqrt(5)*q**3*(-2*Omega*m1*r + I)*C3Product(l, m, 0, l1, m1, -1, 4, 0, 1)*HertzFunc(l1, m1, 0)*muCoupling(l1, 2) + 2574*sqrt(5)*q**3*(HertzDaggerFunc(l1, m1, 0) + HertzFunc(l1, m1, 0))*C3Product(l, m, 0, 2, 0, 0, l1, m1, 0)*muCoupling(l1, 1)*muCoupling(l1, 2) + 1716*q**3*(HertzDaggerFunc(l1, m1, 0) + HertzFunc(l1, m1, 0))*C3Product(l, m, 0, 4, 0, 0, l1, m1, 0)*muCoupling(l1, 1)*muCoupling(l1, 2) + 2574*sqrt(7)*I*q**2*r*(-HertzDaggerFunc(l1, m1, 0) + HertzFunc(l1, m1, 0))*C3Product(l, m, 0, 3, 0, 0, l1, m1, 0)*muCoupling(l1, 1)*muCoupling(l1, 2) - 286*sqrt(210)*I*q**2*(Omega*m1*(q**2*(-Omega*m1*r + I) - 3*r**2*(Omega*m1*r - 3*I)) + 18*r)*C3Product(l, m, 0, 3, 0, -2, l1, m1, 2)*HertzDaggerFunc(l1, m1, 0) + 286*sqrt(210)*I*q**2*(Omega*m1*(q**2*(-Omega*m1*r + I) - 3*r**2*(Omega*m1*r - 3*I)) + 18*r)*C3Product(l, m, 0, l1, m1, -2, 3, 0, 2)*HertzFunc(l1, m1, 0) + 572*sqrt(21)*q**2*(-2*I*Omega*m1*q**2 - 3*r)*C3Product(l, m, 0, 3, 0, -1, l1, m1, 1)*HertzDaggerFunc(l1, m1, 0)*muCoupling(l1, 2) + 572*sqrt(21)*q**2*(2*I*Omega*m1*q**2 + 3*r)*C3Product(l, m, 0, l1, m1, -1, 3, 0, 1)*HertzFunc(l1, m1, 0)*muCoupling(l1, 2) + 429*sqrt(30)*I*q*(q**2*(6*I*Omega*m1*r + 3) + 7*r**2*(2*I*Omega*m1*r + 3))*C3Product(l, m, 0, 2, 0, -1, l1, m1, 1)*HertzDaggerFunc(l1, m1, 0)*muCoupling(l1, 2) + 429*sqrt(30)*I*q*(q**2*(6*I*Omega*m1*r + 3) + 7*r**2*(2*I*Omega*m1*r + 3))*C3Product(l, m, 0, l1, m1, -1, 2, 0, 1)*HertzFunc(l1, m1, 0)*muCoupling(l1, 2) + 3003*sqrt(3)*I*r*(3*q**2 + 5*r**2)*(-HertzDaggerFunc(l1, m1, 0) + HertzFunc(l1, m1, 0))*C3Product(l, m, 0, 1, 0, 0, l1, m1, 0)*muCoupling(l1, 1)*muCoupling(l1, 2) + 429*sqrt(6)*(I*Omega*m1*(3*q**4 - 35*r**4) + 7*r*(q**2 - 5*r**2))*C3Product(l, m, 0, l1, m1, -1, 1, 0, 1)*HertzFunc(l1, m1, 0)*muCoupling(l1, 2) + 429*sqrt(6)*(-3*I*Omega*m1*q**4 - 7*q**2*r + 35*r**3*(I*Omega*m1*r + 1))*C3Product(l, m, 0, 1, 0, -1, l1, m1, 1)*HertzDaggerFunc(l1, m1, 0)*muCoupling(l1, 2))/90090

# %% [markdown]
# ## $h_{23}$

# %%
expr="(((-6*r*(q^2 + (-2 + r)*r) - I*m*Omega*(q^2 + r^2)*(q^2 + 3*r^2))*HertzDaggerFunc[l, m, 0] + (q^2 + (-2 + r)*r)*(q^2 + 3*r^2)*HertzDaggerFunc[l, m, 1])*muCoupling[l, 2])/(12*Sqrt[2]*(q^2 + (-2 + r)*r))"
math_expr=parse_mathematica(expr)
print(math_expr)
# Out:
# sqrt(2)*((q**2 + 3*r**2)*(q**2 + r*(r - 2))*HertzDaggerFunc(l, m, 1) + (-I*Omega*m*(q**2 + r**2)*(q**2 + 3*r**2) - 6*r*(q**2 + r*(r - 2)))*HertzDaggerFunc(l, m, 0))*muCoupling(l, 2)/(24*(q**2 + r*(r - 2)))

# %%
expr="(Sqrt[Pi]*q*(7*Sqrt[3]*m1*Omega*C3Product[l, m, 1, 1, 0, -1, l1, m1, 2]*(-(m1*Omega*(q^2 + r^2)*(q^2 + 5*r^2)*HertzDaggerFunc[l1, m1, 0]) - I*(q^2 + (-2 + r)*r)*(-10*r*HertzDaggerFunc[l1, m1, 0] + (q^2 + 5*r^2)*HertzDaggerFunc[l1, m1, 1])) + q*(m1*Omega*(q^2 + r^2)*HertzDaggerFunc[l1, m1, 0] + I*(q^2 + (-2 + r)*r)*HertzDaggerFunc[l1, m1, 1])*(14*Sqrt[15]*C3Product[l, m, 1, 2, 0, -1, l1, m1, 2] - 2*Sqrt[42]*m1*Omega*q*C3Product[l, m, 1, 3, 0, -1, l1, m1, 2] - (7*I)*Sqrt[10]*C3Product[l, m, 1, 2, 0, 0, l1, m1, 1]*muCoupling[l1, 2])))/(210*(q^2 + (-2 + r)*r))"
math_expr=parse_mathematica(expr)
print(math_expr)
# Out:
# sqrt(pi)*q*(7*sqrt(3)*Omega*m1*(-Omega*m1*(q**2 + r**2)*(q**2 + 5*r**2)*HertzDaggerFunc(l1, m1, 0) - I*(q**2 + r*(r - 2))*(-10*r*HertzDaggerFunc(l1, m1, 0) + (q**2 + 5*r**2)*HertzDaggerFunc(l1, m1, 1)))*C3Product(l, m, 1, 1, 0, -1, l1, m1, 2) + q*(Omega*m1*(q**2 + r**2)*HertzDaggerFunc(l1, m1, 0) + I*(q**2 + r*(r - 2))*HertzDaggerFunc(l1, m1, 1))*(-2*sqrt(42)*Omega*m1*q*C3Product(l, m, 1, 3, 0, -1, l1, m1, 2) + 14*sqrt(15)*C3Product(l, m, 1, 2, 0, -1, l1, m1, 2) - 7*sqrt(10)*I*C3Product(l, m, 1, 2, 0, 0, l1, m1, 1)*muCoupling(l1, 2)))/(210*q**2 + 210*r*(r - 2))

# %% [markdown]
# ## $h_{24}$

# %%
expr="(((6*r*(q^2 + (-2 + r)*r) + I*m*Omega*(q^2 + r^2)*(q^2 + 3*r^2))*HertzFunc[l, m, 0] - (q^2 + (-2 + r)*r)*(q^2 + 3*r^2)*HertzFunc[l, m, 1])*muCoupling[l, 2])/(12*Sqrt[2]*(q^2 + (-2 + r)*r))"
math_expr=parse_mathematica(expr)
print(math_expr)
# Out:
# sqrt(2)*(-(q**2 + 3*r**2)*(q**2 + r*(r - 2))*HertzFunc(l, m, 1) + (I*Omega*m*(q**2 + r**2)*(q**2 + 3*r**2) + 6*r*(q**2 + r*(r - 2)))*HertzFunc(l, m, 0))*muCoupling(l, 2)/(24*(q**2 + r*(r - 2)))

# %%
expr="(Sqrt[Pi]*q*(7*Sqrt[3]*m1*Omega*C3Product[l, m, -1, l1, m1, -2, 1, 0, 1]*(-(m1*Omega*(q^2 + r^2)*(q^2 + 5*r^2)*HertzFunc[l1, m1, 0]) - I*(q^2 + (-2 + r)*r)*(-10*r*HertzFunc[l1, m1, 0] + (q^2 + 5*r^2)*HertzFunc[l1, m1, 1])) - q*(m1*Omega*(q^2 + r^2)*HertzFunc[l1, m1, 0] + I*(q^2 + (-2 + r)*r)*HertzFunc[l1, m1, 1])*(14*Sqrt[15]*C3Product[l, m, -1, l1, m1, -2, 2, 0, 1] + 2*Sqrt[42]*m1*Omega*q*C3Product[l, m, -1, l1, m1, -2, 3, 0, 1] - (7*I)*Sqrt[10]*C3Product[l, m, -1, l1, m1, -1, 2, 0, 0]*muCoupling[l1, 2])))/(210*(q^2 + (-2 + r)*r))"
math_expr=parse_mathematica(expr)
print(math_expr)
# Out:
# sqrt(pi)*q*(7*sqrt(3)*Omega*m1*(-Omega*m1*(q**2 + r**2)*(q**2 + 5*r**2)*HertzFunc(l1, m1, 0) - I*(q**2 + r*(r - 2))*(-10*r*HertzFunc(l1, m1, 0) + (q**2 + 5*r**2)*HertzFunc(l1, m1, 1)))*C3Product(l, m, -1, l1, m1, -2, 1, 0, 1) - q*(Omega*m1*(q**2 + r**2)*HertzFunc(l1, m1, 0) + I*(q**2 + r*(r - 2))*HertzFunc(l1, m1, 1))*(2*sqrt(42)*Omega*m1*q*C3Product(l, m, -1, l1, m1, -2, 3, 0, 1) + 14*sqrt(15)*C3Product(l, m, -1, l1, m1, -2, 2, 0, 1) - 7*sqrt(10)*I*C3Product(l, m, -1, l1, m1, -1, 2, 0, 0)*muCoupling(l1, 2)))/(210*q**2 + 210*r*(r - 2))

# %% [markdown]
# ## $h_{33}$

# %%
expr="(-(m*Omega*(q^4*(-2*I + m*Omega*r) + r^3*(2*I + r*(-2*I + m*Omega*r)) + 2*q^2*r*(3*I + r*(-2*I + m*Omega*r)))*HertzDaggerFunc[l, m, 0]) + (q^2 + (-2 + r)*r)*((4*r - (2*I)*(-I + m*Omega*r)*(q^2 + r^2))*HertzDaggerFunc[l, m, 1] + r*(q^2 + (-2 + r)*r)*HertzDaggerFunc[l, m, 2]))/(4*(q^2 + (-2 + r)*r)^2)"
math_expr=parse_mathematica(expr)
print(math_expr)
# Out:
# (-Omega*m*(q**4*(Omega*m*r - 2*I) + 2*q**2*r*(r*(Omega*m*r - 2*I) + 3*I) + r**3*(r*(Omega*m*r - 2*I) + 2*I))*HertzDaggerFunc(l, m, 0) + (q**2 + r*(r - 2))*(r*(q**2 + r*(r - 2))*HertzDaggerFunc(l, m, 2) + (4*r - 2*I*(q**2 + r**2)*(Omega*m*r - I))*HertzDaggerFunc(l, m, 1)))/(4*(q**2 + r*(r - 2))**2)

# %%
expr="((-1/2*I)*Sqrt[Pi/3]*q*C3Product[l, m, 2, 1, 0, 0, l1, m1, 2]*((2*I)*m1*Omega*(q - r)*(q + r)*HertzDaggerFunc[l1, m1, 0] + m1^2*Omega^2*(q^2 + r^2)^2*HertzDaggerFunc[l1, m1, 0] + (q^2 + (-2 + r)*r)*((2*I)*m1*Omega*(q^2 + r^2)*HertzDaggerFunc[l1, m1, 1] - (q^2 + (-2 + r)*r)*HertzDaggerFunc[l1, m1, 2])))/(q^2 + (-2 + r)*r)^2"
math_expr=parse_mathematica(expr)
print(math_expr)
# Out:
# -sqrt(3)*I*sqrt(pi)*q*(Omega**2*m1**2*(q**2 + r**2)**2*HertzDaggerFunc(l1, m1, 0) + 2*I*Omega*m1*(q - r)*(q + r)*HertzDaggerFunc(l1, m1, 0) + (q**2 + r*(r - 2))*(2*I*Omega*m1*(q**2 + r**2)*HertzDaggerFunc(l1, m1, 1) - (q**2 + r*(r - 2))*HertzDaggerFunc(l1, m1, 2)))*C3Product(l, m, 2, 1, 0, 0, l1, m1, 2)/(6*(q**2 + r*(r - 2))**2)

# %% [markdown]
# ## $h_{44}$

# %%
expr="(-(m*Omega*(q^4*(-2*I + m*Omega*r) + r^3*(2*I + r*(-2*I + m*Omega*r)) + 2*q^2*r*(3*I + r*(-2*I + m*Omega*r)))*HertzFunc[l, m, 0]) + (q^2 + (-2 + r)*r)*((4*r - (2*I)*(-I + m*Omega*r)*(q^2 + r^2))*HertzFunc[l, m, 1] + r*(q^2 + (-2 + r)*r)*HertzFunc[l, m, 2]))/(4*(q^2 + (-2 + r)*r)^2)"
math_expr=parse_mathematica(expr)
print(math_expr)
# Out:
# (-Omega*m*(q**4*(Omega*m*r - 2*I) + 2*q**2*r*(r*(Omega*m*r - 2*I) + 3*I) + r**3*(r*(Omega*m*r - 2*I) + 2*I))*HertzFunc(l, m, 0) + (q**2 + r*(r - 2))*(r*(q**2 + r*(r - 2))*HertzFunc(l, m, 2) + (4*r - 2*I*(q**2 + r**2)*(Omega*m*r - I))*HertzFunc(l, m, 1)))/(4*(q**2 + r*(r - 2))**2)

# %%
expr="((I/2)*Sqrt[Pi/3]*q*C3Product[l, m, -2, l1, m1, -2, 1, 0, 0]*((2*I)*m1*Omega*(q - r)*(q + r)*HertzFunc[l1, m1, 0] + m1^2*Omega^2*(q^2 + r^2)^2*HertzFunc[l1, m1, 0] + (q^2 + (-2 + r)*r)*((2*I)*m1*Omega*(q^2 + r^2)*HertzFunc[l1, m1, 1] - (q^2 + (-2 + r)*r)*HertzFunc[l1, m1, 2])))/(q^2 + (-2 + r)*r)^2"
math_expr=parse_mathematica(expr)
print(math_expr)
# Out:
# sqrt(3)*I*sqrt(pi)*q*(Omega**2*m1**2*(q**2 + r**2)**2*HertzFunc(l1, m1, 0) + 2*I*Omega*m1*(q - r)*(q + r)*HertzFunc(l1, m1, 0) + (q**2 + r*(r - 2))*(2*I*Omega*m1*(q**2 + r**2)*HertzFunc(l1, m1, 1) - (q**2 + r*(r - 2))*HertzFunc(l1, m1, 2)))*C3Product(l, m, -2, l1, m1, -2, 1, 0, 0)/(6*(q**2 + r*(r - 2))**2)
